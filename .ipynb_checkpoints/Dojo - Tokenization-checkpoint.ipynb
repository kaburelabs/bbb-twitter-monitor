# %%
import pandas as pd
import sqlite3
import string
import re
import pt_core_news_sm
from spacy import displacy
import plotly_express as px
# Read sqlite query results into a pandas DataFrame

import numpy as np

# %%
con = sqlite3.connect("tweets.sqlite")
df = pd.read_sql_query("SELECT * from tweet", con)

len_df = len(df)
unique_list = df.nunique()

# %%
print(len_df)
print(unique_list)
# Out:
# 3101
# index                   1
# created_at            355
# tweet_id             3101
# id_user              2597
# text                 1169
# lang                   18
# location             1023
# device                  7
# reply                  34
# is_RT                   2
# retweet_user          492
# retweet_shares       1315
# retweet_likes        1530
# retweet_reply         267
# retweet_url           695
# is_quote                2
# quoted_user           162
# quoted_shares         412
# quoted_likes          608
# quoted_reply          215
# orig_tweet_quoted     215
# dtype: int64

# %%
df[df.index.isin(df.text.drop_duplicates(keep='last').index)].sort_values('retweet_likes', ascending=False)[:20]
# Out:
#       index                  created_at             tweet_id          id_user  \
# 3067      0  2020-03-23 23:44:04.000000  1242235697064480770       Santos_NOW
# 2997      0  2020-03-23 23:43:56.000000  1242235663128432641     JoaoFidelis_
# 2987      0  2020-03-23 23:43:54.000000  1242235657038303238      Emilly_Kopp
# 2836      0  2020-03-23 23:43:37.000000  1242235584921382914         flapitaz
# 3096      0  2020-03-23 23:44:08.000000  1242235713090920448       LourosaGod
# 1734      0  2020-03-23 23:41:33.000000  1242235061807853575  Kariininhaborge
# 1934      0  2020-03-23 23:41:57.000000  1242235163490299907   NestorSilva13_
# 1306      0  2020-03-23 23:40:42.000000  1242234849919938560         Arthu_rH
# 1400      0  2020-03-23 23:40:52.000000  1242234892487974912  cidinhaWilliams
# 2541      0  2020-03-23 23:43:03.000000  1242235439441940486         agnes_gs
# 857       0  2020-03-23 23:39:53.000000  1242234644600426497        httpbxprt
# 1083      0  2020-03-23 23:40:17.000000  1242234745662078979        _Anasouz_
# 3091      0  2020-03-23 23:44:06.000000  1242235707340599297       xuliaaa___
# 1561      0  2020-03-23 23:41:12.000000  1242234977581969408    grta_infernal
# 2676      0  2020-03-23 23:43:18.000000  1242235506341154816        enairA_VL
# 2523      0  2020-03-23 23:43:01.000000  1242235434383572994  BiancaaQueiroz_
# 975       0  2020-03-23 23:40:06.000000  1242234700137148417         vause_np
# 3028      0  2020-03-23 23:44:00.000000  1242235679771369472        celloucao
# 690       0  2020-03-23 23:39:32.000000  1242234557149184001   Milena17206780
# 664       0  2020-03-23 23:39:28.000000  1242234539575050241      tomlinsnart
#
#                                                    text lang  \
# 3067  A cara da Marcela com a eliminação do Daniel v...   pt
# 2997  RT @Itspedrito: O Prior se tornou um ídolo do ...   pt
# 2987  RT @LwithP: e foi nesse momento em que não pas...   pt
# 2836  RT @PriAlcantara: SE O DANIEL SAIR EU LANÇO UM...   pt
# 3096  Eu queria que vocês se preocupassem com a saúd...   pt
# 1734  RT @PrizellyInfos: Fizeram um remix do Prior f...   pt
# 1934  Gizelly e Felipe flertando. Esse é o tweet. 😂 ...   pt
# 1306   Pribu ou Brior? #BBB2020 https://t.co/WbFqpHtFM4   pt
# 1400  + somos fora Daniel pelos fatos de que tem coi...   pt
# 2541  RT @liderbabu: E essa reação do BABU minha gen...   pt
# 857   RT @crisayonara: a anitta assistindo a prova b...   pt
# 1083  gizelly debochando do discurso do babu sobre t...   pt
# 3091  RT @ntvnasredes: Babu se emociona ao escolher ...   pt
# 1561  Prior: “Por que o pessoal come um teco e deixa...   pt
# 2676  RT @MainyMedeiros: A beleza da Ivy meu pai, pr...   pt
# 2523  RT @lmjstussy: O corona vírus esperando você s...   pt
# 975   RT @PriAlcantara: EU NUNCA VI O BRASIL TÃO FEL...   pt
# 3028  olha britto sinceramente por mim poderia sair ...   pt
# 690   RT @aIfinetei: antes da amizade com prior / de...   pt
# 664   olha britto sinceramente por mim poderia sair ...   pt
#
#                           location         device reply  is_RT  ...  \
# 3067      Capão Redondo, São Paulo        Android  None      1  ...
# 2997                          None         iPhone  None      1  ...
# 2987             Ariquemes, Brasil        Android  None      1  ...
# 2836                          None         iPhone  None      1  ...
# 3096              Itaocara, Brasil         iPhone  None      1  ...
# 1734                   Franca - SP         iPhone  None      1  ...
# 1934        Partenon, Porto Alegre        Android  None      1  ...
# 1306                          None        Android  None      1  ...
# 1400  Brasil /Los Angeles Tomorrow        Android  None      1  ...
# 2541             São Paulo, Brasil         iPhone  None      1  ...
# 857              011 - lado leste          iPhone  None      1  ...
# 1083                           061        Android  None      1  ...
# 3091                             ♐        Android  None      1  ...
# 1561                          None        Android  None      1  ...
# 2676        Rio de Janeiro, Brasil        Android  None      1  ...
# 2523                    Manaus- Am  Mobile device  None      1  ...
# 975     São José do Rio Preto - SP        Android  None      1  ...
# 3028        Belo Horizonte, Brasil           iPad  None      1  ...
# 690                           None         iPhone  None      1  ...
# 664                 princess park.  Mobile device  None      1  ...
#
#      retweet_shares  retweet_likes  retweet_reply          retweet_url  \
# 3067        28672.0       122185.0         1191.0  1241921415793774593
# 2997        21928.0       112703.0         1383.0  1241936241316241410
# 2987        30800.0       101409.0          750.0  1241922265975074821
# 2836         7465.0        92802.0         1902.0  1241925005597966337
# 3096        15722.0        73495.0          250.0  1241929596095823873
# 1734        12767.0        59535.0         1552.0  1241724736813613056
# 1934        18540.0        58763.0          316.0  1241551343459938304
# 1306         8957.0        54461.0          321.0  1241883470743339008
# 1400         6539.0        51744.0         1936.0  1241922073481674752
# 2541         7414.0        48694.0          452.0  1241921268103942144
# 857          6439.0        47939.0          525.0  1241923589240209409
# 1083        11444.0        44520.0          228.0  1239654089572696065
# 3091         4168.0        44040.0          476.0  1242139094441963522
# 1561         7393.0        43900.0          194.0  1241658976225431552
# 2676         5041.0        41901.0          185.0  1234515359052566531
# 2523        13340.0        41815.0          647.0  1241588403919093761
# 975          7631.0        41360.0          553.0  1241918853925535745
# 3028        13703.0        40144.0          148.0  1241926358810472450
# 690          3555.0        40070.0          161.0  1237241330117398528
# 664         13672.0        40036.0          148.0  1241926358810472450
#
#      is_quote   quoted_user quoted_shares quoted_likes quoted_reply  \
# 3067        0          None          None         None         None
# 2997        0          None          None         None         None
# 2987        0          None          None         None         None
# 2836        0          None          None         None         None
# 3096        0          None          None         None         None
# 1734        0          None          None         None         None
# 1934        1     multishow          4821        37168          313
# 1306        1    molholemos          5924        32919          994
# 1400        0          None          None         None         None
# 2541        0          None          None         None         None
# 857         0          None          None         None         None
# 1083        1  felipesprior         15438        84559         2937
# 3091        0          None          None         None         None
# 1561        0          None          None         None         None
# 2676        0          None          None         None         None
# 2523        0          None          None         None         None
# 975         0          None          None         None         None
# 3028        1           bbb           917        15825         3790
# 690         0          None          None         None         None
# 664         1           bbb           915        15816         3788
#
#         orig_tweet_quoted
# 3067                 None
# 2997                 None
# 2987                 None
# 2836                 None
# 3096                 None
# 1734                 None
# 1934  1241544916691562497
# 1306  1241824536376619013
# 1400                 None
# 2541                 None
# 857                  None
# 1083  1239639766796296193
# 3091                 None
# 1561                 None
# 2676                 None
# 2523                 None
# 975                  None
# 3028  1241919291823448064
# 690                  None
# 664   1241919291823448064
#
# [20 rows x 21 columns]

# %%
for

# %%
df.drop_duplicates('text')
# Out:
#       index                  created_at             tweet_id          id_user  \
# 0         0  2020-03-16 19:38:03.000000  1239637068332089345  VictoriaSongBRA
# 1         0  2020-03-16 19:38:03.000000  1239637068827037702    MonsterPOPist
# 2         0  2020-03-16 19:38:03.000000  1239637069401657354    AmandinhaFiaa
# 3         0  2020-03-16 19:38:03.000000  1239637069938515968        xuliazapp
# 4         0  2020-03-16 19:38:03.000000  1239637070240296960     Grazielle180
# ...     ...                         ...                  ...              ...
# 1565      0  2020-03-16 19:40:35.000000  1239637708852670464       BowlPedro7
# 1567      0  2020-03-16 19:40:35.000000  1239637709536313349       JamiVilela
# 1570      0  2020-03-16 19:40:36.000000  1239637711096602624    pepecasonfire
# 1571      0  2020-03-16 19:40:36.000000  1239637711209758720      nobrenobeat
# 1573      0  2020-03-16 19:40:36.000000  1239637711989997568    brunonicola07
#
#                                                    text lang  \
# 0     RT @VictoriaSongBRA: [👑] Sem hate na TL, apena...   pt
# 1     Incentivos para votar no Pyong \n\nPyong deu c...   pt
# 2     ENTAO VAMOS LA! \n\nBAGULHO AQUI É #FICABABU E...   pt
# 3     RT @LucasBGallina: Isso me emociona!\nVINGADOR...   pt
# 4     Prior encontrou um card, ganhou um celular e d...   pt
# ...                                                 ...  ...
# 1565  RT @manugavassi: Beijo da Manuzinha pra vocês ...   pt
# 1567  RT @whomath: daniel e ivy falando que é imposs...   pt
# 1570  SE FOREM CANCELAR O #BBB20 ACHO QUE O THIAGO T...   pt
# 1571  RT @eltonbieber_ofc: A unica final possível, q...   pt
# 1573  @RedeGlobo já quero 24h de #BBB20 pelo amor de...   pt
#
#                            location         device      reply  is_RT  ...  \
# 0     facebook.com/VictoriaSongBRA/         iPhone       None      1  ...
# 1                             VENUS        Android       None      1  ...
# 2               Passo Fundo, Brasil         iPhone       None      0  ...
# 3                                SC        Android       None      1  ...
# 4                  tão tão distante        Android       None      1  ...
# ...                             ...            ...        ...    ...  ...
# 1565          Rio de Janeiro,Brazil  Mobile device       None      1  ...
# 1567                   Aracaju - SE  Mobile device       None      1  ...
# 1570                         Brasil  Mobile device       None      1  ...
# 1571                      VKAOS, RJ  Mobile device       None      1  ...
# 1573                         Brazil         iPhone  RedeGlobo      0  ...
#
#      retweet_shares  retweet_likes  retweet_reply          retweet_url  \
# 0               1.0            0.0            0.0  1239629355841658880
# 1             128.0          846.0           16.0  1239588325759074311
# 2               NaN            NaN            NaN                 None
# 3               1.0            5.0            0.0  1239636903252680705
# 4            4349.0        32094.0          162.0  1239578137219993600
# ...             ...            ...            ...                  ...
# 1565          239.0         2587.0           34.0  1239626561588015105
# 1567          867.0         6184.0          362.0  1239397817162125313
# 1570            2.0            5.0            0.0  1239636409046249475
# 1571         6122.0        34310.0          333.0  1239167453185347589
# 1573            NaN            NaN            NaN                 None
#
#      is_quote     quoted_user quoted_shares quoted_likes quoted_reply  \
# 0           0            None          None         None         None
# 1           0            None          None         None         None
# 2           1  gatinhofofo666           379         1594           88
# 3           1         gguinep          4200        11961          611
# 4           0            None          None         None         None
# ...       ...             ...           ...          ...          ...
# 1565        1             bbb           542         5678          127
# 1567        0            None          None         None         None
# 1570        0            None          None         None         None
# 1571        0            None          None         None         None
# 1573        0            None          None         None         None
#
#         orig_tweet_quoted
# 0                    None
# 1                    None
# 2     1239595605053374466
# 3     1239496288888147969
# 4                    None
# ...                   ...
# 1565  1239615994038976514
# 1567                 None
# 1570                 None
# 1571                 None
# 1573                 None
#
# [555 rows x 21 columns]

# %%
rt_tweets = df[df['is_RT'] == True]
print(f"The percentage of retweets is {round(len(rt_tweets)/len_df * 100)}% of all the tweets")

# The percentage of tweets from the initial set that are replies to tweets of another user
reply_tweets = df[np.logical_not(df['reply'].isin([None]))]
print(f"The percentage of replies is {round(len(reply_tweets) / len_df * 100)}% of all the tweets")

# Percentage of tweets from the initial set that have #mentions and are not retweets
mention_tweets = df[~df['text'].str.contains("RT") & df['text'].str.contains("@")]
print(f"Has mentions in {round(len(mention_tweets)/len(df) * 100)}% of all the tweets that aren't RT")

# How many tweets inside are plain text tweets (No RT or mention)
plain_text_tweets = df[~df['text'].str.contains("@")  & ~df['text'].str.contains("RT")]
print(f"The percentage of retweets is {round(len(plain_text_tweets)/len(df)*100)}% of all the tweets")
# Out:
# The percentage of retweets is 75% of all the tweets
# The percentage of replies is 1% of all the tweets
# Has mentions in 3% of all the tweets that aren't RT
# The percentage of retweets is 56% of all the tweets

# %%
df.drop_duplicates('text')
# Out:
#       index                  created_at             tweet_id          id_user  \
# 0         0  2020-03-16 19:38:03.000000  1239637068332089345  VictoriaSongBRA
# 1         0  2020-03-16 19:38:03.000000  1239637068827037702    MonsterPOPist
# 2         0  2020-03-16 19:38:03.000000  1239637069401657354    AmandinhaFiaa
# 3         0  2020-03-16 19:38:03.000000  1239637069938515968        xuliazapp
# 4         0  2020-03-16 19:38:03.000000  1239637070240296960     Grazielle180
# ...     ...                         ...                  ...              ...
# 1565      0  2020-03-16 19:40:35.000000  1239637708852670464       BowlPedro7
# 1567      0  2020-03-16 19:40:35.000000  1239637709536313349       JamiVilela
# 1570      0  2020-03-16 19:40:36.000000  1239637711096602624    pepecasonfire
# 1571      0  2020-03-16 19:40:36.000000  1239637711209758720      nobrenobeat
# 1573      0  2020-03-16 19:40:36.000000  1239637711989997568    brunonicola07
#
#                                                    text lang  \
# 0     RT @VictoriaSongBRA: [👑] Sem hate na TL, apena...   pt
# 1     Incentivos para votar no Pyong \n\nPyong deu c...   pt
# 2     ENTAO VAMOS LA! \n\nBAGULHO AQUI É #FICABABU E...   pt
# 3     RT @LucasBGallina: Isso me emociona!\nVINGADOR...   pt
# 4     Prior encontrou um card, ganhou um celular e d...   pt
# ...                                                 ...  ...
# 1565  RT @manugavassi: Beijo da Manuzinha pra vocês ...   pt
# 1567  RT @whomath: daniel e ivy falando que é imposs...   pt
# 1570  SE FOREM CANCELAR O #BBB20 ACHO QUE O THIAGO T...   pt
# 1571  RT @eltonbieber_ofc: A unica final possível, q...   pt
# 1573  @RedeGlobo já quero 24h de #BBB20 pelo amor de...   pt
#
#                            location         device      reply  is_RT  ...  \
# 0     facebook.com/VictoriaSongBRA/         iPhone       None      1  ...
# 1                             VENUS        Android       None      1  ...
# 2               Passo Fundo, Brasil         iPhone       None      0  ...
# 3                                SC        Android       None      1  ...
# 4                  tão tão distante        Android       None      1  ...
# ...                             ...            ...        ...    ...  ...
# 1565          Rio de Janeiro,Brazil  Mobile device       None      1  ...
# 1567                   Aracaju - SE  Mobile device       None      1  ...
# 1570                         Brasil  Mobile device       None      1  ...
# 1571                      VKAOS, RJ  Mobile device       None      1  ...
# 1573                         Brazil         iPhone  RedeGlobo      0  ...
#
#      retweet_shares  retweet_likes  retweet_reply          retweet_url  \
# 0               1.0            0.0            0.0  1239629355841658880
# 1             128.0          846.0           16.0  1239588325759074311
# 2               NaN            NaN            NaN                 None
# 3               1.0            5.0            0.0  1239636903252680705
# 4            4349.0        32094.0          162.0  1239578137219993600
# ...             ...            ...            ...                  ...
# 1565          239.0         2587.0           34.0  1239626561588015105
# 1567          867.0         6184.0          362.0  1239397817162125313
# 1570            2.0            5.0            0.0  1239636409046249475
# 1571         6122.0        34310.0          333.0  1239167453185347589
# 1573            NaN            NaN            NaN                 None
#
#      is_quote     quoted_user quoted_shares quoted_likes quoted_reply  \
# 0           0            None          None         None         None
# 1           0            None          None         None         None
# 2           1  gatinhofofo666           379         1594           88
# 3           1         gguinep          4200        11961          611
# 4           0            None          None         None         None
# ...       ...             ...           ...          ...          ...
# 1565        1             bbb           542         5678          127
# 1567        0            None          None         None         None
# 1570        0            None          None         None         None
# 1571        0            None          None         None         None
# 1573        0            None          None         None         None
#
#         orig_tweet_quoted
# 0                    None
# 1                    None
# 2     1239595605053374466
# 3     1239496288888147969
# 4                    None
# ...                   ...
# 1565  1239615994038976514
# 1567                 None
# 1570                 None
# 1571                 None
# 1573                 None
#
# [555 rows x 21 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

len_list = [ len(df), len(rt_tweets),len(mention_tweets), len(reply_tweets), len(plain_text_tweets)]
item_list = ['All Tweets','Retweets', 'Mentions', 'Replies', 'Plain text tweets']
tweets = pd.DataFrame([np.array(i) for i in zip(item_list, len_list)], columns=['Category', 'Total'])

import plotly_express as px

fig = px.bar(tweets[:20], y='Total', x='Category', orientation='v', 
             width=500, height=350, )
fig.update_yaxes(categoryorder='total ascending', title='')
# Out:
# <div>
#
#
#             <div id="a900f430-03c4-4eff-8e5c-8d30cac45464" class="plotly-graph-div" style="height:350px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a900f430-03c4-4eff-8e5c-8d30cac45464")) {
#                     Plotly.newPlot(
#                         'a900f430-03c4-4eff-8e5c-8d30cac45464',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Category=%{x}<br>Total=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["All Tweets", "Retweets", "Mentions", "Replies", "Plain text tweets"], "xaxis": "x", "y": ["1576", "1186", "49", "20", "889"], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 350, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth":  ...

# %% [raw]
# def remove_accent(text):
#     return normalize('NFKD', text).encode('ASCII', 'ignore').decode('ASCII')
#
# hashtag_pattern = re.compile(r"#[a-zA-Z]+")
#
# df.drop_duplicates('text', keep='last')['text'].apply(remove_accent)

# %% [raw]
# hashtags = re.compile(r'\B#\w*[a-zA-Z]+\w*')
#
# df.drop_duplicates('text', keep='last')['text'].apply(hashtags.findall)

# %% [raw]
# df.drop_duplicates('text', keep='last')['text']

# %%
df.text.drop_duplicates()
# Out:
# 0       RT @VictoriaSongBRA: [👑] Sem hate na TL, apena...
# 1       Incentivos para votar no Pyong \n\nPyong deu c...
# 2       ENTAO VAMOS LA! \n\nBAGULHO AQUI É #FICABABU E...
# 3       RT @LucasBGallina: Isso me emociona!\nVINGADOR...
# 4       Prior encontrou um card, ganhou um celular e d...
#                               ...
# 1565    RT @manugavassi: Beijo da Manuzinha pra vocês ...
# 1567    RT @whomath: daniel e ivy falando que é imposs...
# 1570    SE FOREM CANCELAR O #BBB20 ACHO QUE O THIAGO T...
# 1571    RT @eltonbieber_ofc: A unica final possível, q...
# 1573    @RedeGlobo já quero 24h de #BBB20 pelo amor de...
# Name: text, Length: 555, dtype: object

# %%
df.drop_duplicates('text')['text'].apply(remove_accent)
# Out:
# 0       RT @VictoriaSongBRA: [] Sem hate na TL, apenas...
# 1       Incentivos para votar no Pyong \n\nPyong deu c...
# 2       ENTAO VAMOS LA! \n\nBAGULHO AQUI E #FICABABU E...
# 3       RT @LucasBGallina: Isso me emociona!\nVINGADOR...
# 4       Prior encontrou um card, ganhou um celular e d...
#                               ...
# 1565    RT @manugavassi: Beijo da Manuzinha pra voces ...
# 1567    RT @whomath: daniel e ivy falando que e imposs...
# 1570    SE FOREM CANCELAR O #BBB20 ACHO QUE O THIAGO T...
# 1571    RT @eltonbieber_ofc: A unica final possivel, q...
# 1573    @RedeGlobo ja quero 24h de #BBB20 pelo amor de...
# Name: text, Length: 555, dtype: object

# %%
def remove_accent(text):
    return normalize('NFKD', str(text)).encode('ASCII', 'ignore').decode('ASCII')

def hastag_counts(df):
    hashtags = []
    hashtag_pattern = re.compile(r'\B#\w*[a-zA-Z]+\w*')

    df['text'] = df.drop_duplicates('text', keep='last')['text'].apply(remove_accent)
    
    hashtag_matches = list(df['text'].apply(hashtag_pattern.findall))
    
    print(hashtag_matches)
    hashtag_dict = {}
    for match in hashtag_matches:
        for singlematch in match:
            if singlematch not in hashtag_dict.keys():
                hashtag_dict[singlematch] = 1
            else:
                hashtag_dict[singlematch] = hashtag_dict[singlematch]+1

    hashtag_ordered_list =sorted(hashtag_dict.items(), key=lambda x:x[1])
 
    hashtag_ordered_list = hashtag_ordered_list[::-1]
    hashtag_ordered_list = [words for words in hashtag_ordered_list if np.array(words)[0] not in ['#BBB', '#bbb', '#RedeBBB', '#BBBB']]
    #Separating the hashtags and their values into two different lists
    tags_bbb = pd.DataFrame(np.array(hashtag_ordered_list), columns=['#Tags', '#Num'])
    
    return tags_bbb

# %%
def hastag_counts(df):
    hashtags = []
    hashtag_pattern = re.compile(r'\B#\w*[a-zA-Z]+\w*')
    hashtag_matches = list(df.drop_duplicates('text', keep='last')['text'].apply(hashtag_pattern.findall))
    hashtag_dict = {}
    for match in hashtag_matches:
        for singlematch in match:
            if singlematch not in hashtag_dict.keys():
                hashtag_dict[singlematch] = 1
            else:
                hashtag_dict[singlematch] = hashtag_dict[singlematch]+1

    hashtag_ordered_list =sorted(hashtag_dict.items(), key=lambda x:x[1])
    hashtag_ordered_list = hashtag_ordered_list[::-1]
    hashtag_ordered_list = [words for words in hashtag_ordered_list if np.array(words)[0] not in ['#BBB', '#bbb', '#Redebbb',
                                                                                                  '#RedeBBB', '#redebbb', '#bbbb20',
                                                                                                  '#BBBB', "#BBB20", "#bbb20",
                                                                                                  '#bbb2020', '#BBBB20', '#Bbb20',
                                                                                                  '#REDEBBB', "#bbb202O", '#redeBBB',
                                                                                                  '#RedeBBB20', '#BBB2O', '#BBB2O2O',
                                                                                                  '#BBB2O20', '#bbbb20', '#BBBB2O0',
                                                                                                  '#RedeBBBB20', '#BBBB200', '#BBBB2000',
                                                                                                  '#BBB20aovivo', '#BB', '#B', '#BBB2020',
                                                                                                  'BBb20', 'RedeBBBB',  ]]
    #Separating the hashtags and their values into two different lists
    tags_bbb = pd.DataFrame(np.array(hashtag_ordered_list), columns=['#Tags', '#Num'])
    
    return tags_bbb

# %%
hastag_counts(df)[:20]
# Out:
#                              #Tags #Num
# 0                       #ForaPyong   71
# 1                        #ForaBabu   42
# 2                      #FicaPaizao   25
# 3         #ForababuDanielSaiDepois   18
# 4                        #FicaBabu   18
# 5                        #FicaRafa   12
# 6                      #ParedaoBBB    9
# 7                    #ForaPyongLee    8
# 8                       #FicaPyong    8
# 9                 #EmosContraPyong    6
# 10  #ImpeachmentdoBolsonaroURGENTE    6
# 11                        #COVID19    5
# 12                       #gradient    5
# 13                  #fsradiobrasil    5
# 14                      #forapyong    4
# 15                       #FORABABU    4
# 16                       #forababu    4
# 17                       #TeamMari    3
# 18                     #IvyExpulsa    3
# 19                    #TeamGizelly    3

# %%
import plotly_express as px

fig = px.bar(hastag_counts(df)[:20], y='#Tags', x='#Num', orientation='h', 
             width=500, height=500, )
fig.update_yaxes(categoryorder='total ascending', title='')
# Out:
# <div>
#
#
#             <div id="a2ca422e-a0c4-4339-90e0-fa38f3fa64ff" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a2ca422e-a0c4-4339-90e0-fa38f3fa64ff")) {
#                     Plotly.newPlot(
#                         'a2ca422e-a0c4-4339-90e0-fa38f3fa64ff',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "#Num=%{x}<br>#Tags=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["71", "42", "25", "18", "18", "12", "9", "8", "8", "6", "6", "5", "5", "5", "4", "4", "4", "3", "3", "3"], "xaxis": "x", "y": ["#ForaPyong", "#ForaBabu", "#FicaPaizao", "#ForababuDanielSaiDepois", "#FicaBabu", "#FicaRafa", "#ParedaoBBB", "#ForaPyongLee", "#FicaPyong", "#EmosContraPyong", "#ImpeachmentdoBolsonaroURGENTE", "#COVID19", "#gradient", "#fsradiobrasil", "#forapyong", "#FORABABU", "#forababu", "#TeamMari", "#IvyExpulsa", "#TeamGizelly"], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 500, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth":  ...

# %%
def mention_count(df):
    mentions = []
    mention_pattern = re.compile(r"@[a-zA-Z_]+")
    mention_matches = list(df['text'].apply(mention_pattern.findall))
    mentions_dict = {}
    for match in mention_matches:
        for singlematch in match:
            if singlematch not in mentions_dict.keys():
                mentions_dict[singlematch] = 1
            else:
                mentions_dict[singlematch] = mentions_dict[singlematch]+1

    mentions_ordered_list =sorted(mentions_dict.items(), key=lambda x:x[1])
    mentions_ordered_list = mentions_ordered_list[::-1]
    mentions_ordered_list = [words for words in mentions_ordered_list]
    mentions_bbb = pd.DataFrame(np.array(mentions_ordered_list), columns=['@mentions', '#Num'])
    
    return mentions_bbb

# %%
import plotly_express as px

fig = px.bar(mention_count(df)[:20], y='@mentions', x='#Num', orientation='h', 
             width=500, height=500, )
fig.update_yaxes(categoryorder='total ascending', title='')
# Out:
# <div>
#
#
#             <div id="1d94eae1-0cee-47e2-9d01-d98964ea17e8" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1d94eae1-0cee-47e2-9d01-d98964ea17e8")) {
#                     Plotly.newPlot(
#                         '1d94eae1-0cee-47e2-9d01-d98964ea17e8',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "#Num=%{x}<br>@mentions=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["129", "29", "27", "26", "24", "21", "21", "15", "15", "14", "12", "12", "11", "10", "10", "8", "7", "7", "7", "6"], "xaxis": "x", "y": ["@ttkamila", "@UOLBBB", "@thelminha_assis", "@Estrelinha_aa", "@gguinep", "@dennisdjoficial", "@bbb", "@nevereallylover", "@ivamcabral", "@portalprior", "@theufuracao", "@marigonzalez", "@dougoliverx", "@lariknee", "@gizellybicalho_", "@DaieneCr", "@desvendaparcial", "@whomath", "@juliarainha", "@Cauacoments"], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 500, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth":  ...

# %%
def user_counts(df):
    #Going to see who are the users who have tweeted or retweeted the #most and see how
    #Likely it is that they are bots
    usertweets = df.groupby('id_user')
    #Taking the top 25 tweeting users
    top_users = usertweets.count()['text'].sort_values(ascending = False)[:25]
    top_users_dict = top_users.to_dict()
    user_ordered_dict =sorted(top_users_dict.items(), key=lambda x:x[1])
    user_ordered_dict = user_ordered_dict[::-1]
    users_count = [user for user in user_ordered_dict]
    users_bbb = pd.DataFrame(np.array(users_count), columns=['@user', '#Num'])
    
    return users_bbb

# %%
fig = px.bar(user_counts(df)[:20], y='@user', x='#Num', orientation='h', 
             width=500, height=500, )
fig.update_yaxes(categoryorder='total ascending', title='')
# Out:
# <div>
#
#
#             <div id="eabf0822-8982-4b66-9683-8e2f702a4958" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eabf0822-8982-4b66-9683-8e2f702a4958")) {
#                     Plotly.newPlot(
#                         'eabf0822-8982-4b66-9683-8e2f702a4958',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "#Num=%{x}<br>@user=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["5", "4", "4", "4", "4", "4", "3", "3", "3", "3", "3", "3", "3", "3", "3", "3", "3", "3", "2", "2"], "xaxis": "x", "y": ["hornyiyun", "tudonnormal", "suavozvictors", "MonsterPOPist", "champainzzZz", "gabskauff", "Thiago43251767", "ntxlzz", "noveleirinho", "1Dflamess", "nayarajasmin", "brizanchi", "TaissaAlves123", "BnhBrandao", "AlexandreArajo4", "komalovamanda", "EstevaoGabriel9", "andrade_neya", "fuck_gabx", "HevellenAlmeida"], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 500, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth":  ...

# %%
df.loc[np.logical_not(df['device'].isin(['Android', 'iPhone', 'Mobile device'])), 'device'] = 'Others'

# %%
def device_counts(df): 
    #Now lets explore the different devices where the tweets are #produced from and plot these results
    devices = df.groupby('device')
    devicecount = devices['text'].count()
    #Same procedure as the for the mentions, hashtags, etc..
    device_dict = devicecount.to_dict()
    device_ordered_list =sorted(device_dict.items(), key=lambda x:x[1])
    device_ordered_list = device_ordered_list[::-1]
    devices_bbb = pd.DataFrame(np.array(device_ordered_list), columns=['Devices', '#Num'])
    
    return devices_bbb

# %%
fig = px.bar(device_counts(df), y='Devices', x='#Num', orientation='h',
             barmode='relative', width=500, height=300, title='bla')
fig.update_layout(yaxis=dict(categoryorder='total ascending', title=''),
                  xaxis=dict(title=''))
# Out:
# <div>
#
#
#             <div id="e99b1ac5-d0df-4928-99ec-3f998f50852e" class="plotly-graph-div" style="height:300px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e99b1ac5-d0df-4928-99ec-3f998f50852e")) {
#                     Plotly.newPlot(
#                         'e99b1ac5-d0df-4928-99ec-3f998f50852e',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "#Num=%{x}<br>Devices=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "h", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["912", "466", "186", "12"], "xaxis": "x", "y": ["Android", "iPhone", "Mobile device", "Others"], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 300, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %%
#MEAN LENGTH OF THE TWEETS
print("The mean length of the tweets is:", np.mean(df['length']))
#TWEETS WITH AN URL
url_tweets = df[df['text'].str.contains("http")]
print(f"The percentage of tweets with Urls is {round(len(url_tweets)/len(df)*100)}% of all the tweets")
#MEAN TWEETS PER USER
print("Number of tweets per user:", len(df)/df['id_user'].nunique())
# Out:
# The mean length of the tweets is: 182.67658304090506
# The percentage of tweets with Urls is 68% of all the tweets
# Number of tweets per user: 1.6136747802569305

# %%
import string
import re
import nltk
from nltk.tokenize import TweetTokenizer

# %%
df.text[-1:].values
# Out:
# array(['RT @matcomenta: a gente percebe que nunca foi pela CAUSA quando a marcela diz que a MULHER, que se sentiu afetada pra fala machista, que el…'],
#       dtype=object)

# %%
import string
import re
import nltk
from nltk.tokenize import TweetTokenizer
from unicodedata import normalize

punct = [i for i in string.punctuation if i not in ['#', '@']]

def remover_acentos(txt):
    return normalize('NFKD', txt).encode('ASCII', 'ignore').decode('ASCII') 

def strip_links(text):
    link_regex    = re.compile('((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)', re.DOTALL)
    links         = re.findall(link_regex, text)
    for link in links:
        text = text.replace(link[0], ', ')    
    return text

def strip_all_entities(text):
    entity_prefixes = ['@','#']
    for separator in  string.punctuation:
        if separator not in entity_prefixes :
            text = text.replace(separator,' ')
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes:
                words.append(word)
    return ' '.join(words)


def clean_text(text):
    text_strip_links = strip_links(text)
    print(text_strip_links)
    text_strip_hash = strip_all_entities(text_strip_links)
    

    # remove numbers
    text_nonum = re.sub(r'\d+', '', text_strip_hash)
#     print(text_nonum)

    # remove punctuations and convert characters to lower case
    text_nopunct = "".join([char.lower() for char in text_nonum if char not in punct]) 
#     print(text_nopunct)
    text_accents = normalize('NFKD', text_nopunct).encode('ASCII', 'ignore').decode('ASCII')
    # substitute multiple whitespace with single whitespace
    # Also, removes leading and trailing whitespaces
    text_no_doublespace = re.sub('\s+', ' ', text_accents).strip()
    
    return text_no_doublespace

cleaned_tweet = clean_text(df.text[1])
tt = TweetTokenizer()

print(tt.tokenize(cleaned_tweet))
# Out:
# "O que a Globo faz é naturalizar a superioridade numérica branca em um país onde ela não deveria existir e, assim, dificultando as chances da sua audiência se acostumar com vencedores negros no #BBB20"
#
# Meu texto sobre o Babu na @VICEBRASIL
#
# ,
# ['o', 'que', 'a', 'globo', 'faz', 'e', 'naturalizar', 'a', 'superioridade', 'numerica', 'branca', 'em', 'um', 'pais', 'onde', 'ela', 'nao', 'deveria', 'existir', 'e', 'assim', 'dificultando', 'as', 'chances', 'da', 'sua', 'audiencia', 'se', 'acostumar', 'com', 'vencedores', 'negros', 'no', 'meu', 'texto', 'sobre', 'o', 'babu', 'na']

# %%
df.text[:20].apply(clean_text)[3]
# Out:
# 'rt @crisayonara a gizelly me representa kkkkkk @americanascom senta aqui amiga vamos conversar e me patrocina #bbb httpstcocyxwc...'

# %%
df['device'].value_counts(normalize=True)
# Out:
# Android          0.595842
# iPhone           0.271347
# Mobile device    0.126971
# -                0.002453
# Web              0.001869
# iPad             0.001402
# Instagram        0.000117
# Name: device, dtype: float64

# %%
len_df = len(df)
rt_perc = (df['is_RT'].sum() / len_df)
quot_perc = (df['is_quote'].sum() / len_df)
reply_perc = (len(df[np.logical_not(df['reply'].isin([None]))]) / len_df)

print(rt_perc + quot_perc )
# Out:
# 1.0911108515360355

# %%
print('Total Tweets: ', len_df)
print('Unique texts: ', df.text.nunique())
print('Unique Users: ', df.id_user.nunique())
# Out:
# Total Tweets:  8561
# Unique texts:  1940
# Unique Users:  5948

# %%
RT_tweets = df[df['is_RT'] == True]
print(f"The percentage of retweets is {round(len(RT_tweets)/len(df)*100)}% of all the tweets")
# Out:
# The percentage of retweets is 81% of all the tweets

# %%
df['reply'].value_counts()[:5]
# Out:
# bbb              2
# boninho          2
# Nanda_Loren      1
# Juan_corsai      1
# ngela72050363    1
# Name: reply, dtype: int64

# %%
df[np.logical_not(df['reply'].isin([None]))]
# Out:
#      index                  created_at          id_user  \
# 29       0  2020-03-12 19:30:42.000000  Marcio_Jesus_31
# 119      0  2020-03-12 19:30:52.000000      Isabellap01
# 208      0  2020-03-12 19:31:01.000000         silzazbb
#
#                                                   text lang  \
# 29   @GustavoFBahia @TeamGiovanneBR No teu rabo, se...   pt
# 119                    @MarlinOficial  tu quando canta   pt
# 208             @brunoo_macedo https://t.co/1AjyB5IVHW  und
#
#                    location         device          reply  is_RT retweet_user  \
# 29             Salvador, Ba        Android  GustavoFBahia      0         None
# 119  Tijuca, Rio de Janeiro         iPhone  MarlinOficial      0         None
# 208                    None  Mobile device  brunoo_macedo      0         None
#
#     retweet_shares retweet_likes retweet_reply retweet_url  is_quote  \
# 29            None          None          None        None         0
# 119           None          None          None        None         1
# 208           None          None          None        None         1
#
#        quoted_user quoted_shares quoted_likes quoted_reply  \
# 29            None          None         None         None
# 119        lacerda          2858        19030          341
# 208  Lauan_Comenta            34           65            4
#
#        orig_tweet_quoted
# 29                  None
# 119  1238107737160122369
# 208  1238141569141805058

# %%
Reply_tweets = df[np.logical_not(df['reply'].isin([None]))]
print(f"The percentage of retweets is {round(len(Reply_tweets)/len_df*100)}% of all the tweets")
# Out:
# The percentage of retweets is 1% of all the tweets

# %%
quote_and_rt = round(df[df.is_quote.isin([True])]['is_RT'].sum() / len_df * 100, 5)
quote_and_rt
# Out:
# 15.79572

# %%
rt_not_quote = round(df[df.is_quote.isin([False])]['is_RT'].sum() / len_df * 100, 5)
rt_not_quote
# Out:
# 60.19002

# %%
quote_not_rt = round(df[df.is_RT.isin([True])]['is_quote'].sum() / len_df * 100, 5)
quote_not_rt
# Out:
# 15.79572

# %%
replies = round(len(df[df['is_RT'].isin([False]) & df['is_quote'].isin([False])]) / len_df * 100, 5)

replies
# Out:
# 8.45606

# %%
len(df[np.logical_not(df['reply'].isin([None])) ]) / len_df * 100
# Out:
# 2.0902612826603324

# %%
quote_and_rt + rt_not_quote + quote_not_rt + reply
# Out:
# 97.40771999999998

# %%
1238116896035278848
# Out:
# 1238116896035278848

# %%
df[np.logical_not(df['reply'].isin([None]))]
# Out:
#        index                  created_at          id_user  \
# 75         0  2020-03-12 15:16:00.000000      magnusbanej
# 388        0  2020-03-12 15:16:21.000000         lienemec
# 408        0  2020-03-12 15:16:22.000000    gigizinhaszsz
# 448        0  2020-03-12 15:16:25.000000    LeticiaSaenz2
# 560        0  2020-03-12 15:16:32.000000   guinevere_gwen
# ...      ...                         ...              ...
# 28078      0  2020-03-12 15:48:18.000000   crisalmeida40_
# 28254      0  2020-03-12 15:48:30.000000    santanamartha
# 28301      0  2020-03-12 15:48:33.000000  AndressaSicili2
# 28356      0  2020-03-12 15:48:36.000000        teebranco
# 28544      0  2020-03-12 15:48:50.000000          Zitara6
#
#                                                     text lang  \
# 75     POR DEUS... Obcecado pelo coreano, Prior mostr...   pt
# 388    @luandiegov Homens nao tratem como " rainha " ...   pt
# 408    @yakipura ENGRAÇADO QUE O POVO É TÃO HIPÓCRITA...   pt
# 448     @eumauriciosanto #ForaPrior #Priorexpulso #bbb20  und
# 560    @boninho já ta ficando ridículo. Já q vc não é...   pt
# ...                                                  ...  ...
# 28078            @felipeprior @boninho @RedeGlobo #BBB20  und
# 28254  @patriciavelozzo Sim. Acho que ela é a bola da...   pt
# 28301  @HugoGloss Sabugo foi muito experto em usar is...   pt
# 28356  resumo do que aconteceu durante a festa na cas...  und
# 28544  @lucasp0195 Bem, vamos então valorizar quem nã...   pt
#
#                      location         device            reply  is_RT  \
# 75            Pelotas, Brasil         iPhone          xlaviex      0
# 388                   manaus         Android       luandiegov      0
# 408    Belo Horizonte, Brazil        Android         yakipura      0
# 448         São Paulo, Brasil  Mobile device  eumauriciosanto      0
# 560                 Fortaleza  Mobile device          boninho      0
# ...                       ...            ...              ...    ...
# 28078                    None  Mobile device      felipeprior      0
# 28254      Rio de Janeiro, RJ         iPhone  patriciavelozzo      0
# 28301                    None        Android        HugoGloss      0
# 28356   São Bernardo do Campo         iPhone       hericacomh      0
# 28544                    None  Mobile device       lucasp0195      0
#
#       retweet_user  retweet_shares  retweet_likes  retweet_reply retweet_url  \
# 75            None             NaN            NaN            NaN        None
# 388           None             NaN            NaN            NaN        None
# 408           None             NaN            NaN            NaN        None
# 448           None             NaN            NaN            NaN        None
# 560           None             NaN            NaN            NaN        None
# ...            ...             ...            ...            ...         ...
# 28078         None             NaN            NaN            NaN        None
# 28254         None             NaN            NaN            NaN        None
# 28301         None             NaN            NaN            NaN        None
# 28356         None             NaN            NaN            NaN        None
# 28544         None             NaN            NaN            NaN        None
#
#        is_quote    quoted_user quoted_shares quoted_likes quoted_reply  \
# 75            1  portalspopify           165          534           41
# 388           0           None          None         None         None
# 408           0           None          None         None         None
# 448           0           None          None         None         None
# 560           1       andrssll             1            4            1
# ...         ...            ...           ...          ...          ...
# 28078         0           None          None         None         None
# 28254         0           None          None         None         None
# 28301         0           None          None         None         None
# 28356         1    crisayonara          1706        24165          616
# 28544         0           None          None         None         None
#
#          orig_tweet_quoted
# 75     1238110790743396354
# 388                   None
# 408                   None
# 448                   None
# 560    1238116153735684098
# ...                    ...
# 28078                 None
# 28254                 None
# 28301                 None
# 28356  1237992674000601089
# 28544                 None
#
# [344 rows x 20 columns]

# %%
round(len(df[df['is_RT'].isin([False]) & df['is_quote'].isin([False])]) / len_df * 100, 2)
# Out:
# 7.5

# %%
round(df[df.is_RT.isin([False])]['is_quote'].sum() / len_df * 100, 2)

# %%
quot_perc
# Out:
# 0.2201757764627613

# %%
df[np.logical_not(df['reply'].isin([None]))]
# Out:
#        index                  created_at          id_user  \
# 12         0  2020-03-12 14:26:37.000000   AnaPauIaRenaut
# 105        0  2020-03-12 14:29:08.000000         JujubadM
# 282        0  2020-03-12 14:29:21.000000  Gabriel07Machad
# 549        0  2020-03-12 14:29:40.000000         nejinhro
# 638        0  2020-03-12 14:29:46.000000       PortalGinu
# ...      ...                         ...              ...
# 20308      0  2020-03-12 15:24:37.000000         biskatic
# 20385      0  2020-03-12 15:24:41.000000    mistercat2020
# 20751      0  2020-03-12 15:25:07.000000  priscilagomessg
# 20766      0  2020-03-12 15:25:08.000000            sjunq
# 20964      0  2020-03-12 15:25:23.000000        jaypedrao
#
#                                                     text lang  \
# 12     @clarapeixinho @maria_alves1967 Pra quem não t...   pt
# 105    A verdade é que não da pra defender ninguém ne...   pt
# 282    Absurdo! Após se revoltar com frase machista d...  und
# 549    @abelssues a militância seletiva da nojo #bbb2...   pt
# 638    🥼TWEET DA  DIVULGAÇÃO🥼\n\n➡️ SIGA O @PortalGin...  und
# ...                                                  ...  ...
# 20308  Manu peidou e a Rafa chorou de tanto ri\n\n#fe...   pt
# 20385  Engraçado é gente falando que a Manu já disse ...   pt
# 20751  @ntvnasredes E foi isso que a gente pediu, sim...   pt
# 20766  @lirj_sn NA ÉPOCA:\nMari “tem gente que faz AM...   pt
# 20964  resumo do que aconteceu durante a festa na cas...  und
#
#                  location   device            reply  is_RT retweet_user  \
# 12                   None   iPhone    clarapeixinho      0         None
# 105       Interior de SP   Android       FePaesLeme      0         None
# 282         Bahia, Brasil  Android         viccctt_      0         None
# 549       hyuga | she/her  Android        abelssues      0         None
# 638                     🥼  Android  gizellybicalho_      0         None
# ...                   ...      ...              ...    ...          ...
# 20308       Piauí, Brasil   iPhone            oijsk      0         None
# 20385   Sao Paulo, Brazil  Android    mistercat2020      0         None
# 20751    Brasília, Brasil   iPhone      ntvnasredes      0         None
# 20766      Rio de Janeiro  Android          lirj_sn      0         None
# 20964  Vila Velha, Brasil  Android         fabinctl      0         None
#
#        retweet_shares  retweet_likes  retweet_reply retweet_url  is_quote  \
# 12                NaN            NaN            NaN        None         0
# 105               NaN            NaN            NaN        None         1
# 282               NaN            NaN            NaN        None         1
# 549               NaN            NaN            NaN        None         0
# 638               NaN            NaN            NaN        None         1
# ...               ...            ...            ...         ...       ...
# 20308             NaN            NaN            NaN        None         1
# 20385             NaN            NaN            NaN        None         0
# 20751             NaN            NaN            NaN        None         0
# 20766             NaN            NaN            NaN        None         0
# 20964             NaN            NaN            NaN        None         1
#
#           quoted_user quoted_shares quoted_likes quoted_reply  \
# 12               None          None         None         None
# 105        FePaesLeme           101         1197           94
# 282          siteptbr           204         1087           90
# 549              None          None         None         None
# 638        PortalGinu             0            4            1
# ...               ...           ...          ...          ...
# 20308  SCCPAndreStark          3174        19669          324
# 20385            None          None         None         None
# 20751            None          None         None         None
# 20766            None          None         None         None
# 20964     crisayonara          1622        22980          592
#
#          orig_tweet_quoted
# 12                    None
# 105    1238106009186508800
# 282    1238100842810613763
# 549                   None
# 638    1238108968318369793
# ...                    ...
# 20308  1237969854306623488
# 20385                 None
# 20751                 None
# 20766                 None
# 20964  1237992674000601089
#
# [247 rows x 20 columns]

# %%
import numpy as np

round(len(df[np.logical_not(df['reply'].isin([None]))]) / len(df) * 100, 2)
# Out:
# 1.2

# %%
round(len(df[np.logical_not(df['reply'].isin([None]))]) / len(df) * 100, 2)

# %%
df['is_quote'].value_counts(normalize=True)[:5]
# Out:
# 0    0.770146
# 1    0.229854
# Name: is_quote, dtype: float64

# %%
df['is_RT'].value_counts(normalize=True)[:5]
# Out:
# 1    0.782967
# 0    0.217033
# Name: is_RT, dtype: float64

# %%
t = df.drop_duplicates('text', keep='last')

# %%
from datetime import timedelta

df['created_at'] = pd.to_datetime(df['created_at']) - timedelta(hours=3)
df.set_index('created_at', inplace=True)

# %%
df.tail(5)
# Out:
#                      index          id_user  \
# created_at
# 2020-03-12 00:16:55      0     livia_diniz_
# 2020-03-12 00:16:55      0       moraess_le
# 2020-03-12 00:16:56      0          deeh_ps
# 2020-03-12 00:16:56      0  PalomaF68310819
# 2020-03-12 00:16:56      0  KAAH_FONTYNELLI
#
#                                                                   text lang  \
# created_at
# 2020-03-12 00:16:55  Bota o copo no teu rabo, na bundinha da sua mu...   pt
# 2020-03-12 00:16:55  RT @gizellybicalho_: Iti muito fofinho, @rafak...   pt
# 2020-03-12 00:16:56  Só lembrando que ela entrou como obstetra e sa...   pt
# 2020-03-12 00:16:56  Se o Pyong pode colocar essa carta na boca sem...   pt
# 2020-03-12 00:16:56  RT @thomassantanas: Daniel não se sinta um mer...   pt
#
#                                    location     retweet_user  retweet_shares  \
# created_at
# 2020-03-12 00:16:55                Campinas             None             NaN
# 2020-03-12 00:16:55    Praia Grande, Brasil  gizellybicalho_           514.0
# 2020-03-12 00:16:56  Rio de Janeiro, Brasil     SeriesBrasil          1591.0
# 2020-03-12 00:16:56                    None  ViniciusAugust7             1.0
# 2020-03-12 00:16:56                    None   thomassantanas           674.0
#
#                      retweet_likes  retweet_reply          retweet_url  \
# created_at
# 2020-03-12 00:16:55            NaN            NaN                 None
# 2020-03-12 00:16:55         3033.0           70.0  1237934938709798913
# 2020-03-12 00:16:56         5150.0           25.0  1237556578108067841
# 2020-03-12 00:16:56            1.0            0.0  1237940447751921666
# 2020-03-12 00:16:56         2199.0           14.0  1237934676121128961
#
#                     quoted_user  quoted_shares  quoted_likes  quoted_reply  \
# created_at
# 2020-03-12 00:16:55        None            NaN           NaN           NaN
# 2020-03-12 00:16:55        None            NaN           NaN           NaN
# 2020-03-12 00:16:56        None            NaN           NaN           NaN
# 2020-03-12 00:16:56        None            NaN           NaN           NaN
# 2020-03-12 00:16:56        None            NaN           NaN           NaN
#
#                     orig_tweet_quoted
# created_at
# 2020-03-12 00:16:55              None
# 2020-03-12 00:16:55              None
# 2020-03-12 00:16:56              None
# 2020-03-12 00:16:56              None
# 2020-03-12 00:16:56              None

# %%
df.resample('1min').count()['index'].sort_index(ascending=False).reset_index()[1:]
# Out:
#             created_at  index
# 1  2020-03-12 00:15:00   1106
# 2  2020-03-12 00:14:00   1172
# 3  2020-03-12 00:13:00   1191
# 4  2020-03-12 00:12:00   1180
# 5  2020-03-12 00:11:00   1134
# 6  2020-03-12 00:10:00   1139
# 7  2020-03-12 00:09:00    989
# 8  2020-03-12 00:08:00    921
# 9  2020-03-12 00:07:00   1080
# 10 2020-03-12 00:06:00   1187
# 11 2020-03-12 00:05:00   1215
# 12 2020-03-12 00:04:00   1239
# 13 2020-03-12 00:03:00   1340
# 14 2020-03-12 00:02:00   1277
# 15 2020-03-12 00:01:00   1268
# 16 2020-03-12 00:00:00   1150
# 17 2020-03-11 23:59:00   1194
# 18 2020-03-11 23:58:00   1151
# 19 2020-03-11 23:57:00   1297
# 20 2020-03-11 23:56:00   1206
# 21 2020-03-11 23:55:00   1344
# 22 2020-03-11 23:54:00   1425
# 23 2020-03-11 23:53:00   1472
# 24 2020-03-11 23:52:00   1286
# 25 2020-03-11 23:51:00   1213
# 26 2020-03-11 23:50:00    965
# 27 2020-03-11 23:49:00   1040
# 28 2020-03-11 23:48:00   1037
# 29 2020-03-11 23:47:00   1015
# 30 2020-03-11 23:46:00    990
# 31 2020-03-11 23:45:00   1057
# 32 2020-03-11 23:44:00   1018
# 33 2020-03-11 23:43:00   1150
# 34 2020-03-11 23:42:00   1103
# 35 2020-03-11 23:41:00   1054
# 36 2020-03-11 23:40:00   1123
# 37 2020-03-11 23:39:00    672

# %% [markdown]
# ### Searching an specific word in the data - Filtering

# %%
# create a filter series matching "coppola"
mask = t['text'].str.lower().str.contains("daniel")

# look at text only from matching rows
t[mask][['text']].head(10)
# Out:
#                                                   text
# 12   Pyong corta o daniel no meio hj por favor ou f...
# 22   Pra mim, essa é a ordem em sequência  de ELIMI...
# 25   Desliguei o povo ninguém merece essa câmera ne...
# 46   RT @azucarebanana: O prior perguntando se o Da...
# 117  RT @Carolina20Mari1: Desliguei o povo ninguém ...
# 132  https://t.co/imM13XmMXr\nGenteee babado 🤣🤣🤣🤣\n...
# 160  E uma das #fadas disse que #Guilherme não teve...
# 205  Eu quero saber onde que a Flay gritou com o no...
# 282  Puta q pariu O Daniel se for lider vai fazer u...
# 291  #BBB20 gente o Daniel é maconheiro ahhahahahahaha

# %%
df.quoted_user.value_counts()
# Out:
# luizguiprado    134
# lacerda          97
# bbb              53
# UOLBBB           50
# _naratb          38
#                ...
# GabiGuie          1
# tuitafranco       1
# ttvzeiro          1
# Manugravasse      1
# luizabay          1
# Name: quoted_user, Length: 284, dtype: int64

# %%
df['count'] = df.groupby(["text"])["created_at"].transform("count")

# %%
df['count'] > 5
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 6473    False
# 6474    False
# 6475    False
# 6476     True
# 6477    False
# Name: count, Length: 6478, dtype: bool

# %%
def _update_div1(df_):

    #df = pd.read_sql_query("SELECT text from tweet", con)
    df_['count'] = df_.groupby(["text"])["created_at"].transform("count")
    df_princ = df_.drop_duplicates('text', keep='last').sort_values('count', ascending=False)[['text', 'count', 'retweet_shares']][:20].rename(columns={'retweet_shares':'# RT'})
    df_princ1 = df_.drop_duplicates('text', keep='last').sort_values('retweet_shares', ascending=False)[['text', 'retweet_shares', 'count']].rename(columns={'retweet_shares':'# RT'})

    return [df_princ.to_dict('rows'), df_princ1.to_dict('rows')]

_update_div1(df)
# Out:
# [[{'text': 'RT @_naratb: Prior e Manu dublando. Gente, KKKKKKKKKKKKKKKKKKKK\n\n#BBB20 https://t.co/6ePNLKPqHQ',
#    'count': 316,
#    '# RT': 26957.0},
#   {'text': 'manu: "babu, você quer que eu faça alguma coisa pra você comer?"\n\nbabu: "pode ser...você te dar essa chance".\n\nmanu: "sério? que honra!\n\n*manu termina de fazer o pão com ovo*\n\nmanu: "espero que você goste".\n\nbabu: "você gostar sim, tem carinho e amor". #bbb20 https://t.co/ai4VflIjDB',
#    'count': 242,
#    '# RT': 12764.0},
#   {'text': 'Eu gosto da amizade dos dois, mas nunca vou esquecer qnd os caras tavam numa rodinha e eles cortavam o babu em tds as vezes que ele ia falar e depois saíram andando e não ouviram ele. O Felipe é amigo do babu pq é a pessoa que sobrou e não pq ele sempre foi prioridade',
#    'count': 167,
#    '# RT': 11034.0},
#   {'text': 'Rafa tá desesperada por causa da manu desde sexta, orou, chorou, pediu por ela no raio-x, abraçou, secou as lágrimas, ajudou arrumar a mala, usou a mesma cor de roupa só pra amiga se sentir bem, mas ninguém lembra dessa amizade pq amizade feminina não é relevante #BBB20 https://t.co/tuucAvdFpo',
#    'count': 128,
#    '# RT': 8953.0},
#   {'text': 'a gizelly matando a marcela “ ela é advogada e beija e chora e grita e sabe pq? pq ela é ser humano “ e ela faz tudo #bbb20 #bbb2020 https://t.co/Whyx1VyrsI',
#    'count': 99,
#    '# RT': 4877.0},
#   {'text': 'Babu culpou Gabi pelo Guilherme ter saído \nBabu falou que a postura da Gizelly não é de uma advogada\nBabu disse que o assédio é culpa da própria mulher.\nBabu só usa argumentos de "não sabe lavar uma louça" pra Manu\nBabu disse que mulher é cardápio\n\nMULHER NÃO É CARDÁPIO #BBB20 https://t.co/4dWvckF80F',
#    'count': 98,
#    '# RT': 957.0},
#   {'text': 'Que nojo, e aí vão passar pano ou bombar essa tag que nem foi com todos os outros participantes? Seletividade aqui não\n\nUsem: MULHER NÃO É CARDÁPIO BABU #bbb20  https://t.co/iYif7dv6Ls',
#    'count': 79,
#    '# RT': 1342.0},
#   {'text': 'RT @enquuete: SE O PRÓXIMO PAREDÃO FOR ESSE QUEM VOCÊS SALVA? \n\nPRIOR: RT \nGIGI: FAV \n#BBB20 #BBBB20 \n( ah pedidos) https://t.co/93fX99OD6d',
#    'count': 76,
#    '# RT': 2679.0},
#   {'text': 'Atacaram a Ivy e a Marcela qd elas fizeram o comentário gordofóbico sobre o Babu. O Prior fez o mesmo, na FRENTE dele e quando Babu tentou explicar pra ele que ele tava desrespeitando, ele ignorou. Não eram vocês que criticavam militância seletiva? #BBB20 https://t.co/qEdiRqdMw1',
#    'count': 71,
#    '# RT': nan},
#   {'text': 'RT @portalprior: Não posso legendar isso kkkkkkkkkkkkkkkkkkkk 🔞 #BBB20 \n\n https://t.co/siYr6yUvHE',
#    'count': 65,
#    '# RT': 70.0},
#   {'text': 'E com 85% dos votos, Victor Hugo até então, é o participante que teve o maior percentual de votos, nem Petrix e Hadson atingiram essa marca. Recorde esse de VH que só poderá ser quebrada por uma unica outra pessoa apenas: Daniel Sabugo! \n\nME PROMETAM!!!\n\n#BBBB20 #BBB20 https://t.co/0idsERwFPw',
#    'count': 62,
#    '# RT': 27445.0},
#   {'text': 'RT @pedrohales: o babu é um exemplo de vítima do racismo estrutural, não finjam que isso é normal #bbb20 https://t.co/QoSAiM2mJH',
#    'count': 60,
#    '# RT': 15489.0},
#   {'text': 'A casa com um monte de “militante” e só quem abraça o Babu é o cara que é o machista e a única mina preta\n\nIsso diz muito sobre com quem a militância fala\nNão é crítica, é reflexão #bbb20 https://t.co/wAHPaRKdBi',
#    'count': 56,
#    '# RT': 19573.0},
#   {'text': 'Música: Dancela\nArtista: @rafaportugalc \n#RedeBBB #BBB20 https://t.co/mLPyEhluOE',
#    'count': 54,
#    '# RT': nan},
#   {'text': 'Prior, Pyong e Babu zoam Daniel falando como seria a festa do líder dele e ele conta uma experiência inusitada. #BBB20 https://t.co/FaOjZfHi9E',
#    'count': 53,
#    '# RT': 39.0},
#   {'text': 'MULHER NÃO É CARDÁPIO CONCORDO, ASSIM COMO RACISMO NÃO É BRINCADEIRA, DIZER QUE A COMIDA DE UMA PESSOA TA MACUMBADA TBM NÃO É, GORDOFOBIA TBM NÃO É BRINCADEIRA, BORA PROVAR QUE NÃO SÃO SELETIVOS E LEVANTAR TODAS AS TAGS ???, ACHO QUE NÃO NÉ TORCIDA DO GRUPÃO DA HIPOCRISIA #BBB20',
#    'count': 51,
#    '# RT': 1056.0},
#   {'text': 'RT @mayaranadine: Missionária Rafa e Thelminha que nunca erraram tendo uma visão perfeita do jogo #BBB20 https://t.co/X3V2mrjHkT',
#    'count': 48,
#    '# RT': 3000.0},
#   {'text': 'RT @bbb: Música: Dancela\nArtista: @rafaportugalc \n#RedeBBB #BBB20 https://t.co/mLPyEhluOE',
#    'count': 48,
#    '# RT': 35278.0},
#   {'text': 'RT @vagsner: MEU DEUS EU AMO A INTERNET KKKKKKKKKKKKKKKKKKKKKK #BBB20 https://t.co/nReTVlSxmG',
#    'count': 47,
#    '# RT': 14090.0},
#   {'text': 'RT @LucasBGallina: Para os outros é “macho escroto”, para os seus “foi zoeira”. E assim caminha a hipocrisia.',
#    'count': 46,
#    '# RT': 12062.0}],
#  [{'text': 'RT @bbb: Música: Dancela\nArtista: @rafaportugalc \n#RedeBBB #BBB20 https://t.co/mLPyEhluOE',
#    '# RT': 35278.0,
#    'count': 48},
#   {'text': 'E com 85% dos votos, Victor Hugo até então, é o participante que teve o maior percentual de votos, nem Petrix e Hadson atingiram essa marca. Recorde esse de VH que só poderá ser quebrada por uma unica outra pessoa apenas: Daniel Sabugo! \n\nME PROMETAM!!!\n\n#BBBB20 #BBB20 https://t.co/0idsERwFPw',
#    '# RT': 27445.0,
#    'count': 62},
#   {'text': 'RT @_naratb: Prior e Manu dublando. Gente, KKKKKKKKKKKKKKKKKKKK\n\n#BBB20 https://t.co/6ePNLKPqHQ',
#    '# RT': 26957.0,
#    'count': 316},
#   {'text': 'RT @danieltuita: não via uma final tão ruim desde alemanha x argentina na copa de 2014',
#    '# RT': 26264.0,
#    'count': 2},
#   {'text': 'RT @oppscausey: pyong: bom dia\nbabu: bom dia o crlh\n\nAAAAAAAAAAAAAAAAAAAKKKKKKKKKKKKKKKKKKKKKKKKKKK #BBB20 https://t.co/mCn0ns3wLU',
#    '# RT': 26240.0,
#    'count': 1},
#   {'text': 'flay: "se ela (marcela) passar a mão na cabeça dele (daniel) depois de uma coisa dessa, pra mim não faz sentido nada do que ela fez até agora" \n\nMEU DEUS A FLAY PEGOU O SENSATAVIRUS #bbb20 https://t.co/5xo6gn4dgc',
#    '# RT': 14003.0,
#    'count': 7},
#   {'text': 'RT @jdbrmadrid: e o daniel que deu banana pro prior mas n deu pra marcela  #BBB20 https://t.co/PxH6hcvNTg',
#    '# RT': 13262.0,
#    'count': 19},
#   {'text': 'RT @Gi_Almv: O mico meu pai \nDaniel: "não, não vou conseguir"\nMarcela: "puta que pariu" #BBB20 https://t.co/OGJKjIqkjZ',
#    '# RT': 13253.0,
#    'count': 1},
#   {'text': 'RT @multishow: 🚨 30s pra defender a permanência na casa!  🚨 \nBabu: \n#RedeBBB #BBB20 https://t.co/ARGBcudoYr',
#    '# RT': 13180.0,
#    'count': 1},
#   {'text': 'RT @fab8785a4a1048b: E racista sim so não ve quem é cego \n\nMARCELA MENTIROSA #BBB20 https://t.co/wXOs5Oatg3',
#    '# RT': 13149.0,
#    'count': 2},
#   {'text': "prior ''mano a marcela tá perdidinha no jogo ô babu. você acha que o publico tá curtindo ver ela passar a mão na cabeça do daniel mesmo quando ele tá errado? eu tenho certeza que o publico não gosta de hipocrisia''\n\nMEU DEUS MATOU O JOGO DA LOIRINHA DO SUS! #BBB20",
#    '# RT': 12952.0,
#    'count': 8},
#   {'text': 'manu: "babu, você quer que eu faça alguma coisa pra você comer?"\n\nbabu: "pode ser...você te dar essa chance".\n\nmanu: "sério? que honra!\n\n*manu termina de fazer o pão com ovo*\n\nmanu: "espero que você goste".\n\nbabu: "você gostar sim, tem carinho e amor". #bbb20 https://t.co/ai4VflIjDB',
#    '# RT': 12764.0,
#    'count': 242},
#   {'text': 'RT @lacerda: ISSO FOI BONITO D+ BICHO #BBB20 https://t.co/qMiwmwG6CI',
#    '# RT': 12657.0,
#    'count': 11},
#   {'text': 'PRIOR DIZENDO PARA O BABU: SE EU GANHAR O PODER SUPREMO, EU COLOCO A MARCELA E O SALSICHA NO PAREDÃO, TODO MUNDO FALA QUE EU SÓ QUERO A CABEÇA DA GIZELLY, NÃO É ISSO, SIMPLESMENTE EU SÓ QUERO TESTAR TODO MUNDO, EU QUERO TESTAR TODOS"\n\nE O PRIOR NÃO ERRA NUNCA #BBB20',
#    '# RT': 12323.0,
#    'count': 3},
#   {'text': 'RT @LucasBGallina: Para os outros é “macho escroto”, para os seus “foi zoeira”. E assim caminha a hipocrisia.',
#    '# RT': 12062.0,
#    'count': 46},
#   {'text': 'RT @LucasBGallina: Para os outros é “macho escroto”, para os seus “foi zoeira”. E assim caminha a hipocrisia. https://t.co/06guesyNSs',
#    '# RT': 12053.0,
#    'count': 3},
#   {'text': 'RT @bicaIhu: o daniel é um mimado do caralho que não podem dizer um A pra ele que ele fica putinho mesmo estando errado #BBB20 https://t.co…',
#    '# RT': 12004.0,
#    'count': 3},
#   {'text': 'Eu gosto da amizade dos dois, mas nunca vou esquecer qnd os caras tavam numa rodinha e eles cortavam o babu em tds as vezes que ele ia falar e depois saíram andando e não ouviram ele. O Felipe é amigo do babu pq é a pessoa que sobrou e não pq ele sempre foi prioridade',
#    '# RT': 8010.0,
#    'count': 1},
#   {'text': 'RT @babi: O rafa portugal zuando marcela e daniel foi o auge do programa de hj #bbb20  https://t.co/rKkvX0Bmuw',
#    '# RT': 7730.0,
#    'count': 3},
#   {'text': 'Vocês estão vendo o ESFORÇO DAS MENINAS pra passar pano pro machismo do Daniel?\n\nMarcela chegou a dizer que "ele deve ter algo em câncer"\nSIM, ELA JUSTIFICOU MACHISMO COM SIGNO\n\nCaralho 85% do victor hugo tem que ser pouco perto dela e daniel #bbb20 https://t.co/f1ZcudtdU3',
#    '# RT': 7666.0,
#    'count': 34},
#   {'text': 'O estagiário vai largar mais cedo e deixou a matéria pronta: Victor Hugo é o sétimo eliminado do #BBB20 #larguei  https://t.co/u4Za1eOMUJ https://t.co/9ysTW0sSLJ',
#    '# RT': 7134.0,
#    'count': 1},
#   {'text': 'RT @lacerda: thelma ta muito cedo pra jantar a marcela #BBB20  https://t.co/fzomMBL8WV',
#    '# RT': 7031.0,
#    'count': 3},
#   {'text': 'RT @crisayonara: fernanda keulla teve a melhor reação de todos os campeões do bbb esse é o tweet #bbb20 https://t.co/Ood6WHt2hC',
#    '# RT': 7021.0,
#    'count': 6},
#   {'text': 'Felipe Prior:\n\n- Bota no paredão reclama\n- não bota no paredão reclama\n- tá na xepa reclama\n- diz que se for convidado pra ir pro VIP vai recusar o convite\n- não é convidado pra nada reclama\n- é convidado pro cinema do líder reclama\n\nI N S U P O R T Á V E L\n#BBB20',
#    '# RT': 6841.0,
#    'count': 2},
#   {'text': 'RT @Itspedrito: a flayslany atualizou o meme do victor hugo com o próprio victor hugo #bbb20 https://t.co/7fnMVWtB4n',
#    '# RT': 6659.0,
#    'count': 1},
#   {'text': 'RT @forcabeyovato: “ a gente não ganha isso aqui nem fudendo”  kkkkkkkkkk\ngente que rir da própria desgraça = tudo  #bbb20 https://t.co/4kt…',
#    '# RT': 6451.0,
#    'count': 1},
#   {'text': 'RT @raregomezz: GENTE O VICTOR HUGO PEGOU A CORRENTINHA QUE O GUILHERME DEU PARA A GABI E TROUXE COM ELE, EU TO CHOCADA #BBB20 https://t.co…',
#    '# RT': 6315.0,
#    'count': 34},
#   {'text': 'RT @TBoybutera: Meu a primeira coisa que vejo e abro o twiiter DANIEL BROXANDO \n\nEU:\n\n#BBB20 https://t.co/IFa8wCnDh8',
#    '# RT': 5826.0,
#    'count': 1},
#   {'text': 'RT @LwithP: vc bobeou e a edição debochando com a marcela e o daniel passou na sua timeline #bbb20 #bbbb20 https://t.co/4ODzd44VJH',
#    '# RT': 5709.0,
#    'count': 6},
#   {'text': 'RT @BenjaminUFPA: é daqui pra prior gente!!! não dá mais, MARCELA MENTIROSA, e mente na cara de pau. \n\n#BBB20 https://t.co/buaqOaguqZ',
#    '# RT': 4877.0,
#    'count': 2},
#   {'text': 'a gizelly matando a marcela “ ela é advogada e beija e chora e grita e sabe pq? pq ela é ser humano “ e ela faz tudo #bbb20 #bbb2020 https://t.co/Whyx1VyrsI',
#    '# RT': 4877.0,
#   {'text': 'RT @siteptbr: E o Rafael Portugal faz TUDO! #BBB20\n\n https://t.co/TUeURmkjA5',
#    '# RT': 3474.0,
#    'count': 1},
#   {'text': 'RT @felipesprior: a surra que o prior deu na marcela, ficou até calada. #BBB20 https://t.co/LEGWusIZQE',
#    '# RT': 3248.0,
#    'count': 1},
#   {'text': 'RT @BabuSantana: Obrigado Brasil 🇧🇷\nO barquinho vai continuar...🐻\n@felipeprior #teambabu #bbb20 https://t.co/fJUwkCiFJ6',
#    '# RT': 3247.0,
#    'count': 1},
#   {'text': 'RT @wesleyalvx: marcela tendo uma conversa bastante séria com daniel    #BBB20 https://t.co/SXBgVVLhPg',
#    '# RT': 3190.0,
#    'count': 8},
#   {'text': 'RT @portalprior: Prior: “Agora eu vou expor mesmo.” Kkkkkkkkkkkk AMO #BBB20 https://t.co/IPHj4UOCCq',
#    '# RT': 3115.0,
#    'count': 1},
#   {'text': 'RT @enquuete: AH PEDIDOS \n\nSE O PRÓXIMO PAREDÃO FOR ESSE QUEM VOCÊS SALVA? \n\nRAFA: RT \nPRIOR: FAV #BBB20 #BBBB20 https://t.co/rcw3CnyQYp',
#    '# RT': 3102.0,
#    'count': 22},
#   {'text': 'RT @owcardibr: Cardi B acaba de declarar torcida para a Gizelly do BBB e não choca pela sensatez. 😍 #BBB20',
#    '# RT': 3042.0,
#    'count': 1},
#   {'text': 'RT @Itspedrito: Gente... #BBB20 https://t.co/KZ3rXaB3zZ',
#    '# RT': 3040.0,
#    'count': 10},
#   {'text': 'RT @mayaranadine: Missionária Rafa e Thelminha que nunca erraram tendo uma visão perfeita do jogo #BBB20 https://t.co/X3V2mrjHkT',
#    '# RT': 3000.0,
#    'count': 48},
#   {'text': 'Daniel: " eu não vou conseguir"\nMarcela: "puta que pariu"\n\nÉ Marcela vc trocou um milhão e meio por essa broxada\n\nDANIEL BROXANDO\n#bbb20 #bbb2020 \n\n https://t.co/tMl9lFIw2Z',
#    '# RT': 2885.0,
#    'count': 1},
#   {'text': 'Mais cedo a Manu falou uma frase que eu acho muito importante e vai ser nossa única resposta “a boca fala aquilo que o coração tá cheio”, muita amargura perder o tempo mandando um participante desistir, mas enfim... Sorte e muita luz! #BBB20',
#    '# RT': 2865.0,
#    'count': 4},
#   {'text': 'RT @gabilegalzlnha: QUE HOMENS, MEUS AMIGOS! #BBB20 \nhttps://t.co/yL2vE5Lqe4',
#    '# RT': 2864.0,
#    'count': 2},
#   {'text': 'RT @PriAlcantara: Babu não é meu participante preferido mas eu gostaria muito que ele ganhasse #bbb20',
#    '# RT': 2823.0,
#    'count': 2},
#   {'text': 'RT @gioewbank: Minha Gi furacão!!!! To te esperando pra gente ser BFF 🌹 #bbb20',
#    '# RT': 2819.0,
#    'count': 1},
#   {'text': 'RT @gizellybicalho_: O VT que passou da nossa Gigi Furacão! Confesso que fiquei ate emocionada 🤧♥️ #BBB20 #TeamGizelly https://t.co/YA3a7Je…',
#    '# RT': 2811.0,
#    'count': 2},
#    '# RT': 2247.0,
#    'count': 6},
#   {'text': 'RT @rafakalimann_: Gente o que é isso? Amei essa dublagem 😂😂😂😂 #BBB20  https://t.co/67d4dCXb3O',
#    '# RT': 2129.0,
#    'count': 22},
#   {'text': 'RT @falarafha: a ana clara vendo a realidade paralela em que o victor hugo ta\n\n#bbb20 #redeBBB\n\n https://t.co/QhuM62e3Uv',
#    '# RT': 2077.0,
#    'count': 2},
#   {'text': 'I\'m sorry, the old Manu can\'t come to the phone right now... Why? \nOh...  \nManu: "Eu matei a antiga" \n#RedeBBB #BBB20 https://t.co/qZKVYVAWCM',
#    '# RT': 1975.0,
#    'count': 1},
#   {'text': 'gente acho que vai ser muito difícil de conseguir consciliar assistir big brother brasil com a faculdade...\n\nterei que trancar o curso #bbb20',
#    '# RT': 1876.0,
#    'count': 1},
#   {'text': 'RT @babi: Uma lenda chamada Thelminha 💕 #bbb20  https://t.co/iReFV7vk8m',
#    '# RT': 1808.0,
#    'count': 1},
#   {'text': 'Ontem o Prior disse pro Babu que ele fazia parte de um projeto de ampliação de casa de crianças abandonadas e muita gente atacou falando que era mentira, então eis aqui um vídeo dele com as crianças cantando..\nE você, o que faz pra ajudar o próximo? #BBB20 https://t.co/gqvBvvP4xY',
#    '# RT': 1767.0,
#    'count': 34},
#   {'text': 'o silêncio da militância sobre o babu dizer que quando o prior sair vai ter um CARDÁPIO DE MULHER pra ele escolher é ensurdecedor #BBB20 https://t.co/H6TdrrMyVE',
#    '# RT': 1763.0,
#    'count': 35},
#   {'text': 'RT @intowil: rafael portugal salvando o bbb em 2 minutos este e tuite\n\n#bbb20 https://t.co/ChRcYSypHB',
#    '# RT': 1745.0,
#    'count': 2},
#   {'text': 'RT @crisayonara: VICTOR HUGO ELIMINADO #bbb20  https://t.co/wdGogqLjlS',
#    '# RT': 1704.0,
#    'count': 1},
#   {'text': 'RT @cleytu: E o campeão desse BBB é o Rafael Portugal #bbb20',
#    '# RT': 1698.0,
#    'count': 1},
#   {'text': 'RT @bbb: Gritando até agora com Rafael Portugal 🗣🗣\n#CatBBB completinho de presente para vocês: \n\n#RedeBBB #BBB20 https://t.co/JK87oAHTlA',
#    '# RT': 1697.0,
#    'count': 1},
#   {'text': 'Marcela: "[Pyong] tá assumindo uma posição chata, ninguém é cuidador de ninguém aqui". A gente vai deixar só essa frase no ar.... kkkk #BBB20',
#    '# RT': 1691.0,
#    'count': 1},
#   {'text': '"Eu confesso que eu queria que o Babu tivesse saído." "Eu não. Por pior que seja a sua convivência com ele, o que Victor fez foi mt pior."\n\nThelma 10000000000000 X 0 Ivy #BBB20 https://t.co/BhKD1dbBVJ',
#    '# RT': 1675.0,
#    'count': 2},
#   {'text': 'RT @celebdistorcida: o daniel pra qualquer coisa no #BBB20 https://t.co/gIiMLqpYaP',
#    '# RT': 1662.0,
#    'count': 3},
#   {'text': 'MULHER NÃO É CARDÁPIO CONCORDO, ASSIM COMO RACISMO NÃO É BRINCADEIRA, DIZER QUE A COMIDA DE UMA PESSOA TA MACUMBADA TBM NÃO É, GORDOFOBIA TBM NÃO É BRINCADEIRA, BORA PROVAR QUE NÃO SÃO SELETIVOS E LEVANTAR TODAS AS TAGS ???, ACHO QUE NÃO NÉ TORCIDA DO GRUPÃO DA HIPOCRISIA #BBB20',
#    '# RT': 1056.0,
#    'count': 51},
#   {'text': 'RT @PortalRunik: POPULARIDADE: Vocês estão torcendo, pelo Pyong no programa? #BBB20 #RedeBBB \n\nRT - Sim\nFAV - Não https://t.co/02BdUizweA',
#    '# RT': 1020.0,
#    'count': 2},
#   {'text': 'EU QUERO TODO MUNDO POSTANDO ESSE VÍDEO PRA ENALTECER UM VT DA GIZELLY NO BBB POR LIVRE E ESPONTÂNEA VONTADE DO PROGRAMA #BBB20 https://t.co/tb2PEZwnat',
#    '# RT': 998.0,
#    'count': 8},
#   {'text': 'RT @thelminha_assis: Um pouco do papo da Thelma com a @rafakalimann_ ainda pouco... 👀 #BBB20 /🧡 https://t.co/XYhmtn9hEL',
#    '# RT': 984.0,
#    'count': 3},
#   {'text': 'RT @Itspedrito: Como faz pra ter empatia? #bbb20\n\nhttps://t.co/00BTzqBPFu',
#    '# RT': 979.0,
#    'count': 4},
#   {'text': 'E hoje é AUniversário dele! O cãopanheiro mais lindo e fiel que Gigi Furacão poderia ter. Parabéns, Jack Bacon! 🎊🎉🎁❤️ #BBB20 #TeamGizelly https://t.co/NsCSOVPR9I',
#    '# RT': 967.0,
#    'count': 1},
#   {'text': 'Babu culpou Gabi pelo Guilherme ter saído \nBabu falou que a postura da Gizelly não é de uma advogada\nBabu disse que o assédio é culpa da própria mulher.\nBabu só usa argumentos de "não sabe lavar uma louça" pra Manu\nBabu disse que mulher é cardápio\n\nMULHER NÃO É CARDÁPIO #BBB20 https://t.co/4dWvckF80F',
#    '# RT': 957.0,
#    'count': 98},
#   {'text': 'RT @whomath: thelma eu te amo 🥺🥺🥺🥺 #BBB20 https://t.co/cglp3zJXPJ',
#    '# RT': 949.0,
#    'count': 3},
#   {'text': 'RT @rodpocket: único trisal que já existiu no bbb e victor hugo sonha #bbb20 https://t.co/eJD0oRkESL',
#    '# RT': 947.0,
#    'count': 1},
#   {'text': 'Coisas que a Marcela perdeu:\n• Perdeu a confiança e a amizade verdadeira da Gizelly.\n•Perdeu o amor do público.\n•Perdeu o título de favorita da edição.\n•Perdeu mais de 100K de seguidores no Instagram.\n•Perdeu o prêmio de 1,5M.\n#bbb2020 #BBBB20\n#DanielBroxa https://t.co/tNOJOQLKAo',
#    '# RT': 937.0,
#    'count': 1},
#   {'text': 'RT @cmilasphile: O BERRO QUE EU DEI, MELHOR VÍDEO KKKKKKKKKKKKKKKKK A CARA DA MARCELA VÉI  #BBB20  https://t.co/dbCqa0kivl',
#    '# RT': 933.0,
#    'count': 1},
#   {'text': 'RT @thelminha_assis: Teve feed atualizado com @BabuSantana também! Essa foto 🧡 #BBB20 https://t.co/ry2rWx1CtM',
#    '# RT': 924.0,
#    'count': 2},
#   {'text': 'A arrogância de um personagem criado ou condicionado apenas para RECLAMAR, RECLAMAR, RECLAMAR. Ação típica de pessoas q por incompetência não sabem brilhar por conta própria e acham mais fácil pegar o atalho do VITIMISMO BARATO E CONTRADITÓRIO. Resta saber o tempo de vida. #bbb20 https://t.co/XkCGMqOlib',
#    '# RT': 914.0,
#    'count': 2},
#   {'text': 'Em vários momentos do #BBB20 o racismo contra asiáticos está sendo colocado em tom de comentário e piada. O programa chegou a fazer um VT sobre isso, em tom de piada. As falas são absurdas do: quero abrir o olho desse coreano. A gestos como esse da foto. https://t.co/BGHLueoBck',
#    '# RT': 912.0,
#    'count': 1},
#   {'text': 'MEU SENHOR MEU DEUS SE VC EXISTE FAÇA COM QUE BONINHO FAÇA ALGUM ARRUMADINHO PRO DANIEL FINALMENTE IR PRO PAREDÃO PRA EU TER O PRAZER DE VER ELE SAINDO COM 95% #BBB20 https://t.co/NPtN3xEwqW',
#    '# RT': 892.0,
#    'count': 1},
#   {'text': 'Daniel estava chorando no quarto das meninas. Gizelly explica que não pode passar a mao na cabeça dele só por ser amigo. Se criticaram todas as atitudes machistas da casa, tem que criticar de alguém próximo tb #BBB #BBB20 https://t.co/XchdPIWm6h',
#    '# RT': 892.0,
#    'count': 1},
#   {'text': 'RT @_Nicoll4: Eu toda vez que o Daniel começa a falar \n#BBB20 https://t.co/STgVklZdZ2',
#    '# RT': 873.0,
#    'count': 3},
#   {'text': 'Ainda estou sem reação com o VT, foi algo tão inesperado que eu tô aqui pensando se eu tô sonhando ou é verdade mesmo... OS HUMILHADOS FORAM EXALTADOS, MEUS FURACÕESSSS 🤧❤️🌪 #BBB20 #TeamGizelly https://t.co/FYiZKWdPs7',
#    '# RT': 872.0,
#    'count': 2},
#   {'text': '6 cenários do #bbb20 que fariam O JOGO ficar uma loucura.\n\nPRA MIM:\n1-Babu x Marcela = Babu\n2-Prior x Daniel = Prior\n3-Babu x Daniel = Babu\n4-Flay x Daniel = Flay\n5-Babu x Ivy = Babu\n6-Gizelly x Marcela = Gizelly https://t.co/FVwoOgGoxr',
#    '# RT': 870.0,
#    'count': 1},
#   {'text': 'RT @rafakalimann_: E vamos de mais mimos Ranu... Cada dia mais apaixonada por essa duplinha! 🥺🥃♥️ #BBB20 https://t.co/oGeg1CyRh5',
#    '# RT': 868.0,
#    'count': 1},
#   {'text': 'RT @ValescaOficial: O Prior tá comemorando achando que o Babu ficou por causa dele? #BBB20 hahahahahahahaha',
#    '# RT': 853.0,
#    'count': 1},
#   {'text': 'RT @PortalRunik: POPULARIDADE: Vocês estão torcendo, pela Gizelly no programa? #BBB20 #RedeBBB \n\nRT - Sim\nFAV - Não https://t.co/wY9FMgI40T',
#    '# RT': 852.0,
#    'count': 1},
#   {'text': 'Após contestar TODAS as pessoas da casa do #BBB20, Victor Hugo quebra novo recorde ao desafiar Tiago Leifert ao vivo. https://t.co/fIcQygg6Vc',
#    '# RT': 851.0,
#    'count': 1},
#   {'text': 'É @victorhugotex, o jogo acabou pra você. Nós da equipe da Thelminha desejamos muita luz, paz e muito sucesso. Pedimos aos nossos seguidores para irem até a página do VH e deixar um pouquinho de amor pra ele e pra família. Sem ataques e com muito carinho! #BBB20',
#    '# RT': 851.0,
#    'count': 1},
#   {'text': 'RT @_santistevish: a tempestade andando pela mansão x\n#BBB20\nhttps://t.co/MVMlIsJoYB',
#    '# RT': 849.0,
#    'count': 16},
#   {'text': 'RT @malibulox: o VT da manu extremamente perfeito! #BBB20 https://t.co/N1t62hSgz1',
#    '# RT': 848.0,
#    'count': 1},
#   {'text': 'Deu manutenção externa e prior e babu foram para o quarto \nPrior para Babu: só vamos ficar nos dois neste quarto \nVamos ser vistos como os excluídos e olhou para câmera \nÉ exatamente isso que ele quer passar como excluído e perseguido \nNão cola mais Prior #bbb20',
#    '# RT': 845.0,
#    'count': 6},
#   {'text': 'RT @comentanoiss: Como a gizelly conta /// como foi #BBB20 https://t.co/roMkdNGFAU',
#    '# RT': 840.0,
#    'count': 1},
#   {'text': '"todas as vezes que eu vejo a marcela dançando com o daniel nas festas eu sinto um ranço"\n\nSÉRIO TRAGAM UM PRÊMIO PARA RAFAEL PORTUGAL POR ISSO AQUI 🆘\n#BBB20\n\n https://t.co/dfeRMmW1su',
#    '# RT': 840.0,
#    'count': 1},
#   {'text': 'Pq eu torço pela Gizelly:\n\n✅Autêntica\n✅Pesa bastante razão e emoção(me identifico)\n✅Erra, mas tem disposição pra mudar\n✅Sabe q precisa aprender sobre pautas importantes \n✅Leal\n✅Divertida\n✅Carismática \n✅Espontânea \n✅E se arrisca e se doa pro jogo totalmente\n\n#BBB20',
#    '# RT': 834.0,
#    'count': 2},
#   {'text': 'RT @VemBigBrother: SOCORROOOOOOOO! Acharam um episódio perdido do Chaves no arquivo mofado do SBT 😆 #BBB20 #RedeBBB https://t.co/wjZNh9foVz',
#    '# RT': 831.0,
#    'count': 2},
#   {'text': 'RT @Anny36626921: MULHER NÃO É CARDÁPIO #BBB20\n\nO babu se referindo as mulheres como cardápio.\n\nO Felipe neto: https://t.co/bh6G8IHLdw',
#    '# RT': 826.0,
#    'count': 13},
#   {'text': 'RT @srtalycia_: EU NÃO AGUENTO MAIS VOCÊS KKKKKKKKKKKKKKKKKKKKKK #BBB20\n https://t.co/v6UeyGOpbY',
#    '# RT': 818.0,
#    'count': 7},
#   {'text': 'RT @gizellybicalho_: E o bordão ícone “paixão só de cristo, amor só de mãe” tá de volta 😂 #BBB20 #TeamGizelly https://t.co/Syo8SrGs5Q',
#    '# RT': 808.0,
#    'count': 3},
#   {'text': 'Ivy: “eu confesso que queria que o Babu tivesse saído”\n\nThelma: “eu não! eu acho que, por mais que vocês tenham problema de convivência com o Babu, teve coisa muito pior”\n\nE A THELMA FAZ TUDOO!! \n#bbb20 #bbbb20 https://t.co/67EqB3GcKd',
#    '# RT': 798.0,
#    'count': 1},
#   {'text': 'RT @cmilasphile: “o último que brigou comigo tá lá fora hein” \n\nNA CARA NÃO GIZELLY KKKKKKKKKKKK #BBB20  https://t.co/JXrP6nVuUg',
#    '# RT': 797.0,
#    'count': 3},
#   {'text': 'RT @VTMartinsF: Babu: “Se eu for aí vou quebrar esse negócio na tua cabeça” \n\nMinha mãe todinha KKKKK\n\n#bbb2020\nDANIEL BROXANDO https://t.c…',
#    '# RT': 796.0,
#    'count': 1},
#   {'text': 'RT @moabemm: Quando o Daniel sair da Casa \n\nA casa // o twitter \n\nFlay X Daniel #BBB20 https://t.co/ocJAaqurHw',
#    '# RT': 785.0,
#    'count': 2},
#   {'text': 'RT @DivaDepressao: Assistir o BBB sem a indicação do Daniel no próximo paredão:  #BBB20 https://t.co/rv0AdSdWcZ',
#    '# RT': 780.0,
#    'count': 1},
#   {'text': 'VH sobre Thelma: “Muito planta! Não faz nada dentro da casa! Desiste que vc não tem chance. Se a pessoa não faz nada é melhor sair.”\n\nGente ele não cansa de passar vergonha #BBB20',
#    '# RT': 777.0,
#    'count': 1},
#   {'text': 'RT @moonlnss: E a Ana Maria que já deu microfone sem áudio pro vh  KKKKKKKKK scrr #BBB20 #maisvoce https://t.co/QzQ3cPJ3WA',
#    '# RT': 760.0,
#    'count': 2},
#   {'text': 'RT @sobreobbb1: “Eu não gosto quando mentem que eu gritei não, viu Daniel?”\nFlay x Daniel #BBB20 https://t.co/anKkHURfLx',
#    '# RT': 752.0,
#    'count': 3},
#   {'text': 'RT @gabirolzinha: a gizelly imita a gabi igualzinho, socorro #bbb20 https://t.co/eLCpr8MTRp',
#    '# RT': 749.0,
#    'count': 17},
#   {'text': 'RT @savio097: Isso fica cada vez melhor 😂😂😂😂😂\n#bbb20\n https://t.co/apyQ7Elp5x',
#    '# RT': 747.0,
#    'count': 7},
#   {'text': 'Chorei vendo esse vídeo da Manu pq eu sei o tanto de Hate que ela sofreu a vida toda desde novinha, o tanto ofensas q ela já ouviu por conta do seu jeito de ser. Isso pra ela foi muito bom saber que alguém ainda ama ela, alguém torce por ela porra isso é tão forte #BBB20 #BBBB20 https://t.co/hl4l1UhPME',
#    '# RT': 741.0,
#    'count': 4},
#   {'text': 'RT @lifertxx: sempre que a câmera para nesses dois eles estão falando mal de alguém... engraçado q na edição não passa #BBB20 https://t.co/…',
#    '# RT': 732.0,
#    'count': 30},
#   {'text': 'RT @enquuete: SE O PRÓXIMO PAREDÃO FOR ESSE QUEM VOCÊS SALVA? \n\nBABU: RT \nDANIEL: FAV \n\n#BBB20 #BBBB20 https://t.co/oWZPovMJEI',
#    '# RT': 728.0,
#    'count': 1},
#   {'text': 'RT @gabirolzinha: gizelly: a\nrafa: ela tá muito gata hoje #bbb20 https://t.co/bqDeB4FJT9',
#    '# RT': 724.0,
#    'count': 14},
#   {'text': 'RT @Anny36626921: Militei em cima do Daniel, do Pyong e do Prior.\n\nNÃO IREI PASSAR PANO PRO BABU PQ MULHER NÃO É CARDÁPIO #BBB20 https://t.…',
#    '# RT': 721.0,
#    'count': 2},
#   {'text': 'O programa de terça feira tinha que ser 80% Rafael Portugal... 20% eliminação!\n\nO cara é além do sensacional... e ainda nos representa totalmente!\n\n#BBB20',
#    '# RT': 716.0,
#    'count': 1},
#   {'text': 'RT @bbb: Gabi: "Por isso que eu desconto tudo na comida! Prefiro comida do que pessoas" 🍔🍜🥮 #RedeBBB #BBB20 https://t.co/unYpwzxmQM',
#    '# RT': 713.0,
#    'count': 1},
#   {'text': 'RT @itolindoo: Babu e Prior. A minha final é essa aqui! 💙 #BBB20\n https://t.co/TZ6gmQHnE3',
#    '# RT': 712.0,
#    'count': 1},
#   {'text': 'RT @rtRONALD11: A Manu Gavassi que vcs conheceram //  A Manu Gavassi que eu conheci \n#bbb20 #bbbb20 https://t.co/u2alkvZMVR',
#    '# RT': 699.0,
#    'count': 5},
#   {'text': 'RT @itolindoo: E o Prior sendo enaltecido no Globo Esporte? O pisão no coreano não pode parar! #BBB20 https://t.co/3ye2YaDQk9',
#    '# RT': 698.0,
#    'count': 3},
#   {'text': 'MEU DEUS! \n\nAna Clara finalizando a conversa e Victor Hugo pede pra fazer uma pergunta:\n\n“Em algum momento eu fui o favorito?”\n\nOOOOOOMG!!!!\n\n#BBB #BBB20 #REDEBBB https://t.co/6eEk68PWF6',
#    '# RT': 689.0,
#    'count': 1},
#   {'text': 'Prior ultrapassa Thelma em número de seguidores no Instagram \n\na thelma não cometeu um erro sequer no bbb e tem uma visão ótima do jogo\n\nmas o PRIOR, machista, banalizou feminicidio e zoofilia, tá ganhando mais destaque q ela pq ele é "engraçadinho" e pediu “desculpas”\n\n #bbb20 https://t.co/7DH5pkC57G',
#    '# RT': 689.0,
#    'count': 13},
#   {'text': 'ELE NÃO DEIXOU NADA PRA MIM! Psicólogo Victor Hugo cheira as toalhas que pertenciam a Guilherme e choca pela vergonha alheia.\n#BBB20 https://t.co/Z4djuZl6Oj',
#    '# RT': 687.0,
#    'count': 2},
#   {'text': 'RT @rodpocket: gizelly a campeã pode entregar o prêmio pra ela bolinho #bbb20',
#    '# RT': 687.0,
#    'count': 1},
#   {'text': 'RT @gizellybicalho_: Já preparamos a festa de aniversário? Amanhã o Jack Bacon faz 3 aninhos! 🐶❤️ #TeamGizelly #BBB20 https://t.co/tw2djSrq…',
#    '# RT': 684.0,
#    'count': 2},
#   {'text': '"Você viu a noticia de que um participante do BBB broxou??????"\n\nEu: Qual o problema é normal poxa, nao tem que zoar\n\n"Foi o Daniel"\n\nEu: KKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK\n\nVisconde de Sabubrocha\nDANIEL BROXANDO #BBBB20 #BBB20 https://t.co/gglACeAX3N',
#    '# RT': 679.0,
#    'count': 1},
# ...
#    'count': 2},
#   {'text': 'Fala do comentário (machista sim, não dá pra negar... porém daquele estrutural, né?) do Babu, mas tá no Tinder pra escolher e ser escolhido que nem o que? Isso mesmo, um cardápio. 🤷🏻\u200d♀️ \n\nCês tão é desesperados que a popularidade do cara tá crescendo. #BBB20',
#    '# RT': 2.0,
#    'count': 2},
#   {'text': 'Livrai-mos de todo o MAL! Amém!\nRAFA BLINDADA\n\n#BBBB20 #BBB20 #REDEBBB #BBB2020 #FESTABBB \n@rainhamatoss\nMULHER NÃO É CARDÁPIO https://t.co/ePe6tc89yk',
#    '# RT': 2.0,
#    'count': 3},
#   {'text': 'RT @CentralReality7: #BBB20\n\nPRIOR CHAMANDO O DANIEL DE LESADO AHAHAHAHAHAHAHAH\n\nÉ A MACONHA \nKKKKKKKKKKKKKKKKKKKKK \n\nBOB MARLEY',
#    '# RT': 2.0,
#    'count': 1},
#   {'text': 'RT
# 🚨 ALERTA FOFURA 😜\n\nDona Ivagna que é a mamãe do Victor Hugo passou aqui para agradecer o carinho e apoio que estão recebendo! #BBB20 #RedeBBB https://t.co/gHL8SkUNaE                                                                                                                                                  1
# CANCELADO! \nNão é porque você é negro, favelado “sem privilégios” que te dá o direito de falar o que quiser e ainda desrespeita de tamanha forma as mulheres, vem ver seu cardápio de rejeição aqui fora, Babu! \nMULHER NÃO É CARDÁPIO \n#BBB20 https://t.co/USysUFO8v3                                                1
# Prior: Babu, o Pyong quer fazer uma magia com a gente...\n\nBabu: Qual?\n\nPrior: Fazer a gente sumir da casa\n\nKkkkkkkkkkk\n\n#BBB20                                                                                                                                                                                   1
# Prior:\n - Livinho é aquele que canta gemendo.\nkkkkkkkkkkkkkkkkkkkk\n#bbb20 #redebbb #bbb2020                                                                                                                                                                                                                           1
# É por isso que o Prior vive de comparando ao Marcelo Dourado.\nPq na edição 10 ele foi excluído e perseguido. Ele usa essa estratégia para ganhar... Gente,esse povo não sabe ser autêntico não? Tem q imitar os antigos Brothers? #BBB20 \nMULHER NÃO É CARDÁPIO https://t.co/tgQ6hatVS2                                1
# Name: text, Length: 1534, dtype: int64

# %%
df.drop_duplicates('text', keep='last')[df.retweet_url == '1237724349265842176']
# Out:
# /home/leonardo/anaconda3/envs/tf_gpu2/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#       index                  created_at     id_user  \
# 7         0  2020-03-12 00:04:24.000000   Ismilin16
# 3134      0  2020-03-12 00:12:19.000000  alararafaa
#
#                                                    text lang location  \
# 7     Eu gosto da amizade dos dois, mas nunca vou es...   pt     None
# 3134  Eu gosto da amizade dos dois, mas nunca vou es...   pt     None
#
#      retweet_user  retweet_shares  retweet_likes  retweet_reply  \
# 7           tthif         10817.0        49587.0          383.0
# 3134        tthif         10940.0        50173.0          388.0
#
#               retweet_url   quoted_user  quoted_shares  quoted_likes  \
# 7     1237724349265842176  luizguiprado        19512.0      127095.0
# 3134  1237724349265842176  luizguiprado        19545.0      127365.0
#
#       quoted_reply    orig_tweet_quoted
# 7           1077.0  1237568035533115392
# 3134        1080.0  1237568035533115392

# %%
df.drop_duplicates('text', keep='last').nunique()
# Out:
# index                  1
# created_at            58
# id_user              416
# text                 438
# lang                  11
# location             165
# retweet_user         230
# retweet_shares       203
# retweet_likes        239
# retweet_reply        134
# retweet_url          288
# quoted_user           28
# quoted_shares         27
# quoted_likes          31
# quoted_reply          24
# orig_tweet_quoted     30
# dtype: int64

# %%
droped = df.drop_duplicates('text', keep='last')

# %%
droped[droped['retweet_user'].isin([None]) & droped['quoted_user'].isin([None])].tail(25)
# Out:
#        index                  created_at          id_user  \
# 46162      0  2020-03-12 03:04:37.000000         ruanxsf1
# 46171      0  2020-03-12 03:04:37.000000         isa_crff
# 46173      0  2020-03-12 03:04:37.000000      criss_ellen
# 46182      0  2020-03-12 03:04:38.000000       kiansbiebs
# 46201      0  2020-03-12 03:04:38.000000   themodernguilt
# 46214      0  2020-03-12 03:04:39.000000     EnquetesNews
# 46219      0  2020-03-12 03:04:39.000000     ThatyBalbino
# 46224      0  2020-03-12 03:04:39.000000        Cadimass_
# 46219          Iguatu, Brasil         None             NaN            NaN
# 46224       São Paulo, Brasil         None             NaN            NaN
# 46226                    None         None             NaN            NaN
# 46228  Rio de Janeiro, Brasil         None             NaN            NaN
# 46239                    None         None             NaN            NaN
# 46267        selena faved me.         None             NaN            NaN
# 46269  Rio de Janeiro, Brasil         None             NaN            NaN
# 46272         Vitória, Brasil         None             NaN            NaN
# 46288                  Na sua         None             NaN            NaN
# 46290        Ourinhos, Brasil         None             NaN            NaN
# 46291                    None         None             NaN            NaN
# 46294       São Paulo, Brasil         None             NaN            NaN
# 46295                    None         None             NaN            NaN
# 46298  Belo Horizonte, Brazil         None             NaN            NaN
# 46303             Chicago, IL         None             NaN            NaN
# 46324                    None         None             NaN            NaN
# 46331                    None         None             NaN            NaN
# 46335          Manaus, Brasil         None             NaN            NaN
# 46343                    None         None             NaN            NaN
#
#        retweet_reply retweet_url quoted_user  quoted_shares  quoted_likes  \
# 46162            NaN        None        None            NaN           NaN
# 46171            NaN        None        None            NaN           NaN
# 46173            NaN        None        None            NaN           NaN
# 46182            NaN        None        None            NaN           NaN
# 46201            NaN        None        None            NaN           NaN
# 46214            NaN        None        None            NaN           NaN
# 46219            NaN        None        None            NaN           NaN
# 46224            NaN        None        None            NaN           NaN
# 46226            NaN        None        None            NaN           NaN
# 46228            NaN        None        None            NaN           NaN
# 46239            NaN        None        None            NaN           NaN
# 46267            NaN        None        None            NaN           NaN
# 46269            NaN        None        None            NaN           NaN
# 46272            NaN        None        None            NaN           NaN
# 46288            NaN        None        None            NaN           NaN
# 46290            NaN        None        None            NaN           NaN
# 46291            NaN        None        None            NaN           NaN
# 46294            NaN        None        None            NaN           NaN
# 46295            NaN        None        None            NaN           NaN
# 46298            NaN        None        None            NaN           NaN
# 46303            NaN        None        None            NaN           NaN
# 46324            NaN        None        None            NaN           NaN
# 46331            NaN        None        None            NaN           NaN
# 46335            NaN        None        None            NaN           NaN
# 46343            NaN        None        None            NaN           NaN
#
#        quoted_reply orig_tweet_quoted
# 46162           NaN              None
# 46171           NaN              None
# 46173           NaN              None
# 46182           NaN              None
# 46201           NaN              None
# 46214           NaN              None
# 46219           NaN              None
# 46224           NaN              None
# 46226           NaN              None
# 46228           NaN              None
# 46239           NaN              None
# 46267           NaN              None
# 46269           NaN              None
# 46272           NaN              None
# 46288           NaN              None
# 46290           NaN              None
# 46291           NaN              None
# 46294           NaN              None
# 46295           NaN              None
# 46298           NaN              None
# 46303           NaN              None
# 46324           NaN              None
# 46331           NaN              None
# 46335           NaN              None
# 46343           NaN              None

# %%
len(droped[np.logical_not(droped['retweet_user'].isin([None]) | droped['quoted_user'].isin([None]))])
# Out:
# 7

# %%
ret_quot = len(droped[np.logical_not(droped['retweet_user'].isin([None]) | droped['quoted_user'].isin([None]))])
total_not_ret_quot = len(droped[droped['retweet_user'].isin([None]) & droped['quoted_user'].isin([None])])
total_ret_quot = len(droped) - ret_quot - total_not_ret_quot

total_ret_quot
# Out:
# 309

# %%
# Out:
# 7

# %%
retweet/quoted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-156-9c7ea532d028> in <module>
# ----> 1 retweet/quoted
#
# NameError: name 'retweet' is not defined

# %%
import numpy as np

# %%
df[np.logical_not(df['retweet_user'].isin([None]) | df['quoted_user'].isin([None]))][['id_user', 'retweet_user', 'quoted_user', ]]
# Out:
#              id_user     retweet_user      quoted_user
# 0     kamalamaximoff            tthif     luizguiprado
# 65           twdinah       srtalycia_         Casimiro
# 260    luanasoaressm            tthif     luizguiprado
# 262  OtavioAzevedo02  dinossauroyoshi    paulopontesma
# 316      Jho_Rezende            tthif     luizguiprado
# 344    aldilenereis1        Joaogrs__      fridaskahIo
# 364      AyanaMend28            tthif     luizguiprado
# 382         umagaabs            tthif     luizguiprado
# 389       smoldybrev       srtalycia_         Casimiro
# 451  harmodepressiva        eric4beyo  harmodepressiva
# 452        backthood            tthif     luizguiprado
# 461         xvfailed            tthif     luizguiprado
# 512      castromafe_            tthif     luizguiprado
# 565       pamegomees            tthif     luizguiprado
# 610  clubindaesquina            tthif     luizguiprado
# 714      1dismypride            tthif     luizguiprado
# 717   raquelinhanova            tthif     luizguiprado
# 741       2Ldaniella            tthif     luizguiprado

# %%
len(droped[(droped['retweet_user'].isin([None]) | droped['quoted_user'].isin([None]))])
# Out:
# 431

# %%
df['retweet_user'].isin(df['retweet_user'][-1:].values).sum()
# Out:
# 168

# %%
df.tail(15)
# Out:
#      index                  created_at          id_user  \
# 361      0  2020-03-11 19:38:30.000000        acabado20
# 362      0  2020-03-11 19:38:30.000000      GeanMarcos_
# 363      0  2020-03-11 19:38:30.000000           XndG20
# 364      0  2020-03-11 19:38:30.000000      AyanaMend28
# 365      0  2020-03-11 19:38:30.000000    vitoriarochha
# 366      0  2020-03-11 19:38:30.000000     larabotelho_
# 367      0  2020-03-11 19:38:31.000000   bruschi_rosana
# 368      0  2020-03-11 19:38:31.000000        mialunars
# 369      0  2020-03-11 19:38:31.000000  Ronaldo74785355
# 370      0  2020-03-11 19:38:31.000000        bsaantos3
# 371      0  2020-03-11 19:38:31.000000        Lillyca71
# 372      0  2020-03-11 19:38:31.000000      so__observo
# 373      0  2020-03-11 19:38:31.000000        itzbaekin
# 374      0  2020-03-11 19:38:31.000000           cwamis
# 375      0  2020-03-11 19:38:31.000000         chajudas
#
#                                                   text lang  \
# 361  RT @LwithP: a reação da ana maria ouvindo o vi...   pt
# 362  RT @sensateitodo: EU TÔ PASSANDO MAAAAAAL KKKK...   pt
# 363  RT @lacerda: ISSO FOI BONITO D+ BICHO #BBB20 h...   pt
# 364  Eu gosto da amizade dos dois, mas nunca vou es...   pt
# 365  E com 85% dos votos, Victor Hugo até então, é ...   pt
# 366  RT @bbb: Música: Dancela\nArtista: @rafaportug...   pt
# 367  MEU DEUS! \n\nAna Clara finalizando a conversa...   tl
# 368  RT @prizelly: 💕 Felipe Prior e Gizelly Bicalho...   en
# 369  RT @chicobarney: Chega de notícias, pessoal. C...   pt
# 370  RT @bbb: Música: Dancela\nArtista: @rafaportug...   pt
# 371  RT @almeidacomentaa: Vão lá votar na Mari esqu...   pt
# 372  RT @itolindoo: Gizelly falando para Ivy que Ma...   pt
# 373  bts comeback exo blackpink twice lisa porn hen...   en
# 374  RT @breakidea: o babu falando que o daniel só ...   pt
# 375  Manu: "Babu, você quer que eu faça algo pra vo...   pt
#
#                           location     retweet_user  retweet_shares  \
# 361  Campos dos Goytacazes, Brasil           LwithP          3092.0
# 362                  Papanduva, SC     sensateitodo            55.0
# 363                    Seu Coração          lacerda         12269.0
# 364                   Não-Me-Toque            tthif          6032.0
# 365                        Floripa     SlytherclawZ         25548.0
# 366                     winterhell              bbb         33621.0
# 367                    Valinhos SP             None             NaN
# 368                           None         prizelly            90.0
# 369                           None      chicobarney            62.0
# 370                          Garça              bbb         33622.0
# 371                         Brasil  almeidacomentaa             2.0
# 372                           None        itolindoo             5.0
# 373                           None             None             NaN
# 374                            016        breakidea           520.0
# 375                         pt/eng  kyliemotivation           318.0
#
#      retweet_likes  retweet_reply          retweet_url   quoted_user  \
# 361        20831.0           97.0  1237721314175193094          None
# 362          202.0            6.0  1237793404735586311          None
# 363        91450.0          310.0  1237565655898918912          None
# 364        24916.0          220.0  1237724349265842176  luizguiprado
# 365       128643.0          504.0  1237567028581433345          None
# 366       137400.0         2168.0  1237557260974297089          None
# 367            NaN            NaN                 None     Dantinhas
# 368          487.0           30.0  1227473951443636225          None
# 369          661.0           51.0  1237811388782911488          None
# 370       137400.0         2168.0  1237557260974297089          None
# 371            4.0            0.0  1237576785425883137          None
# 372           48.0            8.0  1237823109333467136          None
# 373            NaN            NaN                 None          None
# 374         2848.0           15.0  1237707966930923523          None
# 375         2713.0           13.0  1237779077555240964          None
#
#      quoted_shares  quoted_likes  quoted_reply    orig_tweet_quoted
# 361            NaN           NaN           NaN                 None
# 362            NaN           NaN           NaN                 None
# 363            NaN           NaN           NaN                 None
# 364        17506.0      114946.0         963.0  1237568035533115392
# 365            NaN           NaN           NaN                 None
# 366            NaN           NaN           NaN                 None
# 367          602.0        9806.0         297.0  1237578170083115008
# 368            NaN           NaN           NaN                 None
# 369            NaN           NaN           NaN                 None
# 370            NaN           NaN           NaN                 None
# 371            NaN           NaN           NaN                 None
# 372            NaN           NaN           NaN                 None
# 373            NaN           NaN           NaN                 None
# 374            NaN           NaN           NaN                 None
# 375            NaN           NaN           NaN                 None

# %%
df.text[9]
# Out:
# 'Sério Missionária?! Tu nem tava na sala qndo o Daniel foi machista e nem tava qndo a Flay falou com ele. Tá dando tua opinião pq?! #BBB20 https://t.co/5JgpvRA9ng'

# %%
compare_list = ['RT', '@caracostranger', 'Victor', 'Hugo', 'eliminado', 'e', 'Pyong', 'provando', 'mais', 'uma', 'vez', 'que', 'o', 'que', 'disse', 'na', 'primeira', 'semana', '#BBB20', 'https://t.co/dkk2p8gwCi']
compare_list2 = ['RT', '@ntvnasredes', 'os', 'MEUS', 'divertidamente', 'apertando', 'os', 'botões', 'ao', 'mesmo', 'tempo', '#RedeBBB', '#BBB20', 'https://t.co/nSNfm3nfYz']
compare_list3 = ['RT' '@universitariaOF' 'Caiu' 'um' 'cisco' 'no' 'meu' 'olho' '\n\nBABU' 'CONTE' 'COMIGO' 'P' 'TUDO' '#bbb20' '#BBB2O' 'https://t.co/80eeDYPPlO']

# %% [markdown]
# ## word_tokenize

# %% [markdown]
# word_tokenize separate words using spaces and punctuations.

# %%
from nltk.tokenize import word_tokenize
word_tokens = []
for sent in compare_list:
    word_tokens.append(word_tokenize(sent))

# %% [markdown]
# ## WordPunctTokenizer

# %% [markdown]
# WordPunctTokenizer splits all punctuations into separate tokens.

# %%
from nltk.tokenize import WordPunctTokenizer
punct_tokenizer = WordPunctTokenizer()
punct_tokens = []
for sent in compare_list:
    punct_tokens.append(punct_tokenizer.tokenize(sent))

# %% [markdown]
# ## RegrexTokenizer

# %%
from nltk.tokenize import RegexpTokenizer

# \w+ matches one or more word character (alphanumeric & underscore)
match_tokenizer = RegexpTokenizer("[\w']+")
match_tokens = []
for sent in compare_list:   
    match_tokens.append(match_tokenizer.tokenize(sent))

# %% [markdown]
# While words such as 'world’s', 'It’s', 'don’t’ are kept as one entity as we want, ‘https://t.co/9z2J3P33Uc' is still split into different words and we lose the “@” character before “datageneral”.

# %% [markdown]
# #### Match on Whitespace

# %% [markdown]
# RegexpTokenizer can also work by matching the gaps. When the parameter gaps=True is added, the matching pattern will be used as the separators.

# %%
## \s+ matches one or more space.
space_tokenizer = RegexpTokenizer("\s+", gaps=True)
space_tokens = []
for sent in compare_list:
    space_tokens.append(space_tokenizer.tokenize(sent))

# %% [markdown]
# ## TweetTokenizer

# %%
from nltk.tokenize import TweetTokenizer
tweet_tokenizer = TweetTokenizer()
tweet_tokens = []
for sent in df.text:
    tweet_tokens.append(tweet_tokenizer.tokenize(sent))

# %%
tweet_tokens[1]
# Out:
# ['RT',
#  '@Mari_Brag',
#  ':',
#  'quando',
#  'vi',
#  '#GloboApoiaPedofilia',
#  'achei',
#  'que',
#  'era',
#  'sobre',
#  'o',
#  'Daniel',
#  'e',
#  'a',
#  'Marcela',
#  '.',
#  '#BBB20',
#  'https://t.co/LI9oYgrRAA']

# %%
import pandas as pd
tokenizers = {'word_tokenize': word_tokens,
             'WordPunctTokenize':punct_tokens,
             'RegrexTokenizer for matching':match_tokens,
             'RegrexTokenizer for white space': space_tokens,
             'TweetTokenizer': tweet_tokens }

df = pd.DataFrame.from_dict(tokenizers)

# %%
df
# Out:
#                     word_tokenize                      WordPunctTokenize  \
# 0                            [RT]                                   [RT]
# 1             [@, caracostranger]                    [@, caracostranger]
# 2                        [Victor]                               [Victor]
# 3                          [Hugo]                                 [Hugo]
# 4                     [eliminado]                            [eliminado]
# 5                             [e]                                    [e]
# 6                         [Pyong]                                [Pyong]
# 7                      [provando]                             [provando]
# 8                          [mais]                                 [mais]
# 9                           [uma]                                  [uma]
# 10                          [vez]                                  [vez]
# 11                          [que]                                  [que]
# 12                            [o]                                    [o]
# 13                          [que]                                  [que]
# 14                        [disse]                                [disse]
# 15                           [na]                                   [na]
# 16                     [primeira]                             [primeira]
# 17                       [semana]                               [semana]
# 18                     [#, BBB20]                             [#, BBB20]
# 19  [https, :, //t.co/dkk2p8gwCi]  [https, ://, t, ., co, /, dkk2p8gwCi]
#
#    RegrexTokenizer for matching RegrexTokenizer for white space  \
# 0                          [RT]                            [RT]
# 1              [caracostranger]               [@caracostranger]
# 2                      [Victor]                        [Victor]
# 3                        [Hugo]                          [Hugo]
# 4                   [eliminado]                     [eliminado]
# 5                           [e]                             [e]
# 6                       [Pyong]                         [Pyong]
# 7                    [provando]                      [provando]
# 8                        [mais]                          [mais]
# 9                         [uma]                           [uma]
# 10                        [vez]                           [vez]
# 11                        [que]                           [que]
# 12                          [o]                             [o]
# 13                        [que]                           [que]
# 14                      [disse]                         [disse]
# 15                         [na]                            [na]
# 16                   [primeira]                      [primeira]
# 17                     [semana]                        [semana]
# 18                      [BBB20]                        [#BBB20]
# 19   [https, t, co, dkk2p8gwCi]       [https://t.co/dkk2p8gwCi]
#
#                TweetTokenizer
# 0                        [RT]
# 1           [@caracostranger]
# 2                    [Victor]
# 3                      [Hugo]
# 4                 [eliminado]
# 5                         [e]
# 6                     [Pyong]
# 7                  [provando]
# 8                      [mais]
# 9                       [uma]
# 10                      [vez]
# 11                      [que]
# 12                        [o]
# 13                      [que]
# 14                    [disse]
# 15                       [na]
# 16                 [primeira]
# 17                   [semana]
# 18                   [#BBB20]
# 19  [https://t.co/dkk2p8gwCi]

# %% [markdown]
# # JSON CHALLENGES

# %%
import json

# Create a summary of a tweet, only showing relevant fields.
def summarize(tweet, extra_fields = None):
    new_tweet = {}
    for field, value in tweet.items():
        if field in ["text", "id_str", "screen_name", "retweet_count", "favorite_count", "in_reply_to_status_id_str", "in_reply_to_screen_name", "in_reply_to_user_id_str", "quoted_status"] and value is not None:
            new_tweet[field] = value
        elif extra_fields and field in extra_fields:
            new_tweet[field] = value
        elif field in ["retweeted_status", "quoted_status", "user"]:
            new_tweet[field] = summarize(value)
    return new_tweet

# %%
# Print out a tweet, with optional colorizing of selected fields.
def dump(tweet, colorize_fields=None, summarize_tweet=True):
    colorize_field_strings = []
    for line in json.dumps(summarize(tweet) if summarize_tweet else tweet, indent=4, sort_keys=True).splitlines():
        colorize = False
        for colorize_field in colorize_fields or []:
            if "\"{}\":".format(colorize_field) in line:       
                print( "\x1b" + line + "\x1b")
                break
        else:
            print( line)

# %%
reply_tweet = {'created_at': 'Thu Mar 12 14:57:25 +0000 2020', 'id': 1238116896035278848, 'id_str': '1238116896035278848', 'text': 'RT @vaidesmaiar: Achou que Daniel ia falar alguma coisa pra se queimar e quem acabou queimado foi ele. Eu berro #BBB20 https://t.co/l2t7sVX…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 325033787, 'id_str': '325033787', 'name': 'Li 🌬️ 🥃', 'screen_name': 'SoueuLih', 'location': 'Sampa', 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1610, 'friends_count': 1400, 'listed_count': 11, 'favourites_count': 66532, 'statuses_count': 121761, 'created_at': 'Mon Jun 27 16:42:52 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '642D8B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_tile': True, 'profile_link_color': '981CEB', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '7AC3EE', 'profile_text_color': '3D1957', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1211060573594632194/jJrIiEWm_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211060573594632194/jJrIiEWm_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners
}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'pt', 'timestamp_ms': '1584025045771'}

# %%
dump(reply_tweet)
# Out:
# {
#     "favorite_count": 0,
#     "id_str": "1238116896035278848",
#     "retweet_count": 0,
#     "retweeted_status": {
#         "favorite_count": 630,
#         "id_str": "1238010626989047808",
#         "retweet_count": 196,
#         "text": "Achou que Daniel ia falar alguma coisa pra se queimar e quem acabou queimado foi ele. Eu berro #BBB20 https://t.co/l2t7sVXikX",
#         "user": {
#             "id_str": "511577335",
#             "screen_name": "vaidesmaiar"
#         }
#     },
#     "text": "RT @vaidesmaiar: Achou que Daniel ia falar alguma coisa pra se queimar e quem acabou queimado foi ele. Eu berro #BBB20 https://t.co/l2t7sVX\u2026",
#     "user": {
#         "id_str": "325033787",
#         "screen_name": "SoueuLih"
#     }
# }

# %%
ret_rt = {'created_at': 'Tue Mar 10 00:21:46 +0000 2020', 'id': 1237171755233562624, 'id_str': '1237171755233562624', 'text': 'RT @FeCastanhari: Pyong nem precisou sair do BBB pra começar a educar uma criança', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 922308888317308928, 'id_str': '922308888317308928', 'name': 'Peralta', 'screen_name': 'KCouteiro', 'location': 'Ji-Paraná, Brasil', 'url': None, 'description': '@eliza_s8 👸', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 264, 'friends_count': 151, 'listed_count': 0, 'favourites_count': 9042, 'statuses_count': 13254, 'created_at': 'Mon Oct 23 03:49:09 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '39FF14', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1147953512753577984/B48P-SyQ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1147953512753577984/B48P-SyQ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/922308888317308928/1581986223', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Mar 09 16:40:58 +0000 2020', 'id': 1237055790948777991, 'id_str': '1237055790948777991', 'text': 'Pyong nem precisou sair do BBB pra começar a educar uma criança', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 226542162, 'id_str': '226542162', 'name': 'Felipe Castanhari', 'screen_name': 'FeCastanhari', 'location': 'Osasco, SP', 'url': 'http://Instagram.com/fecastanhari', 'description': '30 Anos Diretor e Apresentador / Criador do Canal Nostalgia - Contato: business@canalnostalgia.com.br http://youtube.com/fecastanhari', 'translator_type': 'regular', 'protected': False, 'verified': True, 'followers_count': 6693419, 'friends_count': 1248, 'listed_count': 1693, 'favourites_count': 15496, 'statuses_count': 24482, 'created_at': 'Tue Dec 14 12:39:43 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '004855', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': False, 'profile_link_color': 'FF691F', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1044170135810924544/BNPdZhsF_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1044170135810924544/BNPdZhsF_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/226542162/1532413326', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1236860449888571393, 'quoted_status_id_str': '1236860449888571393', 'quoted_status': {'created_at': 'Mon Mar 09 03:44:45 +0000 2020', 'id': 1236860449888571393, 'id_str': '1236860449888571393', 'text': 'velho. é como ensinar uma criança. eu não consigo acreditar nisso. #bbb20 https://t.co/BsKXtvoqNK', 'display_text_range': [0, 73], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2612346372, 'id_str': '2612346372', 'name': '𝕘𝕒𝕓𝕚𝕣𝕠𝕓𝕒', 'screen_name': 'gbmch', 'location': 'sc', 'url': 'http://gabiroba.iluria.com', 'description': 'curso nutrição e faço uns freela de desenho tbm', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 3168, 'friends_count': 805, 'listed_count': 58, 'favourites_count': 148029, 'statuses_count': 122055, 'created_at': 'Tue Jul 08 21:22:03 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'FAB81E', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1235975365379657729/jx1dJy29_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1235975365379657729/jx1dJy29_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2612346372/1525951706', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 9580, 'reply_count': 1455, 'retweet_count': 11480, 'favorite_count': 90561, 'entities': {'hashtags': [{'text': 'bbb20', 'indices': [67, 73]}], 'urls': [], 'user_mentions': [], 'symbols': [], 'media': [{'id': 
'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'pt'}, 'quoted_status_permalink': {'url': 'https://t.co/uWad2Ky83q', 'expanded': 'https://twitter.com/gbmch/status/1236860449888571393', 'display': 'twitter.com/gbmch/status/1…'}, 'is_quote_status': True, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'FeCastanhari', 'name': 'Felipe Castanhari', 'id': 226542162, 'id_str': '226542162', 'indices': [3, 16]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'pt', 'timestamp_ms': '1583799706644'}

json.dumps(ret_rt, indent=4,  sort_keys=True)
# Out:
# '{\n    "contributors": null,\n    "coordinates": null,\n    "created_at": "Tue Mar 10 00:21:46 +0000 2020",\n    "entities": {\n        "hashtags": [],\n        "symbols": [],\n        "urls": [],\n        "user_mentions": [\n            {\n                "id": 226542162,\n                "id_str": "226542162",\n                "indices": [\n                    3,\n                    16\n                ],\n                "name": "Felipe Castanhari",\n                "screen_name": "FeCastanhari"\n            }\n        ]\n    },\n    "favorite_count": 0,\n    "favorited": false,\n    "filter_level": "low",\n    "geo": null,\n    "id": 1237171755233562624,\n    "id_str": "1237171755233562624",\n    "in_reply_to_screen_name": null,\n    "in_reply_to_status_id": null,\n    "in_reply_to_status_id_str": null,\n    "in_reply_to_user_id": null,\n    "in_reply_to_user_id_str": null,\n    "is_quote_status": true,\n    "lang": "pt",\n    "place": null,\n    "quote_count": 0,\n    "quoted_status": {\n        "contributors": null,\n        "coordinates": null,\n        "created_at": "Mon Mar 09 03:44:45 +0000 2020",\n        "display_text_range": [\n            0,\n            73\n        ],\n        "entities": {\n            "hashtags": [\n                {\n                    "indices": [\n                        67,\n                        73\n                    ],\n                    "text": "bbb20"\n                }\n            ],\n            "media": [\n                {\n                    "additional_media_info": {\n                        "monetizable": false\n                    },\n                    "display_url": "pic.twitter.com/BsKXtvoqNK",\n                    "expanded_url": "https://twitter.com/gbmch/status/1236860449888571393/video/1",\n                    "id": 1236860279314616325,\n                    "id_str": "1236860279314616325",\n                    "indices": [\n                        74,\n                        97\n                    ],\n                    "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1236860279314616325/pu/img/Zbp0lFn5U7Sw1vR3.jpg",\n                    "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1236860279314616325/pu/img/Zbp0lFn5U7Sw1vR3.jpg",\n                    "sizes": {\n                        "large": {\n                            "h": 720,\n                            "resize": "fit",\n                            "w": 1280\n                        },\n                        "medium": {\n                            "h": 675,\n                            "resize": "fit",\n                            "w": 1200\n                        },\n                        "small": {\n                            "h": 383,\n                            "resize": "fit",\n                            "w": 680\n                        },\n                        "thumb": {\n                            "h": 150,\n                            "resize": "crop",\n                            "w": 150\n                        }\n                    },\n                    "type": "photo",\n                    "url": "https://t.co/BsKXtvoqNK"\n                }\n            ],\n            "symbols": [],\n            "urls": [],\n            "user_mentions": []\n        },\n        "extended_entities": {\n            "media": [\n                {\n                    "additional_media_info": {\n                        "monetizable": false\n                    },\n                    "display_url": "pic.twitter.com/BsKXtvoqNK",\n                    "expanded_url": "https://twitter.com/gbmch/status/1236860449888571393/video/1",\n                    "id": 1236860279314616325,\n                    "id_str": "1236860279314616325",\n                    "indices": [\n                        74,\n                        97\n                    ],\n                    "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1236860279314616325/pu/img/Zbp0lFn5U7Sw1vR3.jpg",\n    ...

# %%
reply_tweet['created_at']
# Out:
# 'Thu Mar 12 14:57:25 +0000 2020'
